# %%
# import necessary libraries 
import pandas as pd
import os
import textstat
from openai import OpenAI
import json
import re
import requests
from dotenv import load_dotenv
import math
import unicodedata

# %%
import autogen
from autogen import ConversableAgent

# %%
os.environ['OPENAI_API_KEY'] = "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"

# %%
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')
CLIENT = OpenAI(api_key = OPENAI_API_KEY)
OPENAI_MODEL = "gpt-4o"

# %%
llm_config={"model": OPENAI_MODEL}

# %%
# import prompts
from jh_pfx_prompts import example, icd10_example, single_fewshot_icd10_labeling_prompt, writer_prompt,doctor_prompt, readability_checker_prompt, ICD10_LABELER_INSTRUCTION

# %%
#reading levels
PROFESSIONAL = "Professional"
COLLEGE_GRADUATE = "College Graduate"
COLLEGE = "College"
TENTH_TO_TWELTH_GRADE = "10th to 12th grade"
EIGTH_TO_NINTH_GRADE = "8th to 9th grade"
SEVENTH_GRADE = "7th grade"
SIXTH_GRADE = "6th grade"
FIFTH_GRADE = "5th grade"
N_A = "N/A"

# %%
# reading ease variables
fifth_grade = 95
sixth_grade = 85
seventh_grade = 75
eigth_and_ninth_grade = 65
tenth_to_twelfth_grade = 55
college = 40
college_graduate = 20
professional = 5

# %%
def adjust_difference(diff, threshold):
    """Adjust the readability difference based on the threshold."""
    if diff > threshold:
        return diff - threshold
    return 0

# %%
def extract_json_gpt4o(groupchat):
    """
    Extracts the first valid JSON object from the 'content' of messages,
    handling GPT-4o's potential formatting quirks.
    """
    for msg in reversed(groupchat.messages):
        content = msg.get("content", "").strip()

        # Normalize encoding
        content = unicodedata.normalize("NFKC", content)

        # Remove markdown blocks if they exist
        content = re.sub(r"```json|```", "", content).strip()

        # Try direct JSON parsing first
        try:
            return json.loads(content)
        except json.JSONDecodeError:
            pass  # Continue if direct parsing fails

        # Extract JSON from mixed text
        json_match = re.search(r"\{.*?\}", content, re.DOTALL)
        if json_match:
            try:
                return json.loads(json_match.group(0))
            except json.JSONDecodeError:
                pass  # Continue if regex extraction fails

    return None

# %%
def label_icd10s(pfx_outputs_json):
    pfx_icd10_fewshot_examples = ""
    for i, row in df_fewshot.iterrows():
        pfx_icd10_fewshot_examples += icd10_example.format(**row)

    pfx_icd10_codes = []
    for pfx_output in pfx_outputs_json:
        try:
            prompt = single_fewshot_icd10_labeling_prompt.format(
                examples=pfx_icd10_fewshot_examples,
                PFx=pfx_output['PFx']
            )
        except Exception as e:
            print("ERROR: %s" % pfx_output)
            return

        response = CLIENT.chat.completions.create(
            model=OPENAI_MODEL,
            temperature=0.0,
            messages=[
                {"role": "system", "content": "You are an ICD10 medical coder for incidental findings."},
                {"role": "system", "content": prompt}
            ],
            stream=False,
        )
        
        # Create a simple wrapper object with a 'messages' attribute as a list of dictionaries.
        wrapper = type("Wrapper", (), {})()
        # Convert the ChatCompletionMessage to a dictionary.
        wrapper.messages = [{
            "role": response.choices[0].message.role,
            "content": response.choices[0].message.content
        }]
        
        pfx_icd10_codes.append(wrapper)
        
    return list(map(extract_json_gpt4o, pfx_icd10_codes))

# %%
def get_last_agent_response(messages, agent_name):
    for message in messages:
        if message['name'] == agent_name:
            return message["content"]
    return None

# %%
df_eval = pd.read_csv('pfx_incidental_findings.csv', nrows = 30)

# %%
df_eval
# Out:
#    Body Part           Organ           Incidental_Finding ICD10_code  \
# 0    Abdomen  Adrenal Glands              Adrenal Adenoma     D35.00
# 1    Abdomen  Adrenal Glands             Adrenal Hematoma      E27.8
# 2    Abdomen  Adrenal Glands          Adrenal Hyperplasia      E27.0
# 3    Abdomen  Adrenal Glands                 Adrenal Mass      R93.8
# 4    Abdomen  Adrenal Glands     Adrenal Cortical Adenoma     D35.00
# 5    Abdomen  Adrenal Glands        Adrenal Hyperfunction      E27.8
# 6    Abdomen  Adrenal Glands          Adrenal Gland Tumor      D44.7
# 7    Abdomen  Adrenal Glands                 Adrenal Cyst      E27.8
# 8    Abdomen         Bladder         Bladder Diverticulum      N32.3
# 9    Abdomen         Bladder                 Bladder Mass      R93.4
# 10   Abdomen         Bladder      Bladder Wall Thickening      R93.4
# 11   Abdomen         Bladder                Bladder Stone      N21.0
# 12   Abdomen         Bladder                 Bladder Cyst      R93.4
# 13   Abdomen         Bladder             Bladder Calculus      N21.0
# 14   Abdomen         Bladder               Bladder Cancer      C67.9
# 15   Abdomen         Bladder          Bladder Diverticula      N32.3
# 16   Abdomen         Bladder           Neurogenic Bladder      N31.9
# 17   Abdomen     Gallbladder           Gallbladder Polyps      K82.4
# 18   Abdomen     Gallbladder               Cholelithiasis     K80.20
# 19   Abdomen     Gallbladder                  Gallstones      K80.20
# 20   Abdomen     Gallbladder           Gallbladder Sludge      R93.2
# 21   Abdomen     Gallbladder  Gallbladder Wall Thickening      K81.9
# 22   Abdomen     Gallbladder            Gallbladder Tumor      D37.6
# 23   Abdomen     Gallbladder              Adenomyomatosis      K82.8
# 24   Abdomen     Gallbladder        Porcelain Gallbladder      K82.8
# 25   Abdomen     Gallbladder         Gallbladder Agenesis      Q44.0
# 26   Abdomen      Intestines             Intestinal Polyp      K63.5
# 27   Abdomen      Intestines               Diverticulosis     K57.30
# 28   Abdomen      Intestines                 Appendicitis     K35.80
# 29   Abdomen      Intestines                        Ileus      K56.7
#
#                               ICD-10 Code Description
# 0       Benign neoplasm of adrenal gland, unspecified
# 1    Other specified disorders of the adrenal glands.
# 2                     Congenital adrenal hyperplasia.
# 3   Abnormal findings on diagnostic imaging of oth...
# 4       Benign neoplasm of adrenal gland, unspecified
# 5    Other specified disorders of the adrenal glands.
# 6   Neoplasm of uncertain behavior of endocrine gl...
# 7    Other specified disorders of the adrenal glands.
# 8                             Diverticulum of bladder
# 9   Abnormal findings on diagnostic imaging of uri...
# 10  Abnormal findings on diagnostic imaging of uri...
# 11                                Calculus in bladder
# 12  Abnormal findings on diagnostic imaging of uri...
# 13                                Calculus in bladder
# 14         Malignant neoplasm of bladder, unspecified
# 15                            Diverticulum of bladder
# 16  Neuromuscular dysfunction of bladder, unspecified
# 17                               Polyp of gallbladder
# 18  Calculus of gallbladder without cholecystitis,...
# 19  Calculus of gallbladder without cholecystitis,...
# 20  Abnormal findings on diagnostic imaging of oth...
# 21                         Cholecystitis, unspecified
# 22  Neoplasm of uncertain behavior of other and un...
# 23            Other specified diseases of gallbladder
# 24            Other specified diseases of gallbladder
# 25                  Congenital absence of gallbladder
# 26                                     Polyp of colon
# 27  Diverticulosis of large intestine without perf...
# 28                     Unspecified acute appendicitis
# 29                                 Ileus, unspecified

# %%
df_fewshot = pd.read_csv('pfx_fewshot_examples_college.csv')

# %%
def state_transition(last_speaker, groupchat):
    messages = groupchat.messages

    if last_speaker is manager:
        return writer
    elif last_speaker is writer:
        return icd10_labeler 
    elif last_speaker is icd10_labeler:
        return doctor
    elif last_speaker is doctor:
        if "INACCURATE" in messages[-1]["content"]:
            return writer 
        else:
            return readability_checker
    elif last_speaker is readability_checker:
        if "All done!" in messages[-1]["content"]:
            return None 
        else:
            return writer

# %%
# empty list to store results
results = pd.DataFrame(columns=["finding", "ICD10_code", "PFx", "PFx_ICD10_code"])

for i, row in df_eval.iterrows():
    writer = ConversableAgent(
        name = "Writer",
        system_message = writer_prompt.format(Incidental_Finding = row['Incidental_Finding'], Reading_Level = SIXTH_GRADE),
        llm_config = llm_config,
        code_execution_config = False,
        human_input_mode = "NEVER",
    )
        
    doctor = ConversableAgent( 
        name = "Doctor",
        system_message = doctor_prompt.format(Incidental_Finding = row['Incidental_Finding'], ICD10_code = row["ICD10_code"]),
        llm_config = llm_config,
        code_execution_config = False,
        human_input_mode = "NEVER",
    ) 
        
    readability_checker = ConversableAgent(
        name = "Readability_Checker",
        system_message = readability_checker_prompt.format(reading_level = SIXTH_GRADE),
        llm_config = llm_config,
        code_execution_config = False,
        human_input_mode = "NEVER",
    )
    
    icd10_labeler = ConversableAgent(
        name = "ICD10_Labeler",
        system_message = ICD10_LABELER_INSTRUCTION,
        llm_config = llm_config,
        code_execution_config = False,
        human_input_mode = "NEVER",
    )

    # create agent groupchat
    groupchat = autogen.GroupChat(
        agents = [writer, icd10_labeler, doctor, readability_checker],
        messages = [],
        max_round = 20,
        speaker_selection_method = state_transition,
    )
    
    manager = autogen.GroupChatManager(
        groupchat = groupchat, llm_config = llm_config,
    )
    
    groupchat_result = manager.initiate_chat(manager, message = """Please play your specified role in 
    generating a patient friendly explanation of an inicidental MRI finding.""")

    chat = extract_json_gpt4o(groupchat)

    results.loc[i] = {
        "finding": row['Incidental_Finding'],
        "ICD10_code": row['ICD10_code'],
        "PFx": chat.get("PFx", ""),
        "PFx_ICD10_code": chat.get("PFx_ICD10_code", "")
    }
# Out:
# chat_manager (to chat_manager):
#
# Please play your specified role in
#     generating a patient friendly explanation of an inicidental MRI finding.
#
# --------------------------------------------------------------------------------
#
# Next speaker: Writer
#
# params={'messages': [{'content': '\n\n<Prompt>\nPlease generate new <PFx> for the <Incidental Finding>\n\nOutput should be formatted as a json with the following attributes/fields: finding, ICD10_code, PFx\n\nAdditional Instructions:\n1. DO NOT SUGGEST FOLLOW UP STEPS WITH THE DOCTOR\n2. Maintain a formal, informative tone\n3. If you choose to utilize an anology, do not use more than one. Maint\n4. Please generate PFx at a 6th grade Flesch-Kincaid reading level.\n5. Please output PFx in 100 words or more\n\n</Prompt>\n\n<Incidental Finding> \nAdrenal Adenoma \n</Incidental Finding>  \n', 'role': 'system'}, {'content': 'Please play your specified role in \n    generating a patient friendly explanation of an inicidental MRI finding.', 'name': 'chat_manager', 'role': 'user'}], 'model': 'o1-mini'}
# Writer (to chat_manager):
#
# ```json
# {
#   "finding": "Adrenal Adenoma",
#   "ICD10_code": "D35.2",
#   "PFx": "An adrenal adenoma is a noncancerous growth that forms on one of your adrenal glands. These glands are small organs located above your kidneys and are responsible for producing hormones that help regulate various body functions, such as metabolism and stress response. In most cases, adrenal adenomas do not cause any symptoms and are found by accident during imaging tests done for other reasons. They are generally harmless and do not require treatment unless they start producing hormones or grow in size. Regular monitoring may be recommended to ensure that the adenoma remains stable over time. Understanding that this condition is usually benign can provide reassurance."
# }
# ```
#
# --------------------------------------------------------------------------------
#
# Next speaker: ICD10_Labeler
#
# params={'messages': [{'content': '"\n<Context>\nYou are a medical professional knowledgable in ICD10 codes and their corresponding disorders. You\'re tasked with labelling a pateint friendly explanation with the ICD10 code of the described incidental finding.\n</Context>\n<Prompt>\nPlease label the provided response with the ICD10 code of the described incidental finding.\nAdd the following field to the provided response with the ICD10 code you identified: PFx_ICD10_code\nThis is your sole job, do not do anything else.\n</Prompt>\n<Format>\nOutput should be formatted as a json with the following attributes/fields: finding, ICD10_code, PFx, PFx_ICD10_code\n</Format>\n', 'role': 'system'}, {'content': 'Please play your specified role in \n    generating a patient friendly explanation of an inicidental MRI finding.', 'name': 'chat_manager', 'role': 'user'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous growth that forms on one of your adrenal glands. These glands are small organs located above your kidneys and are responsible for producing hormones that help regulate various body functions, such as metabolism and stress response. In most cases, adrenal adenomas do not cause any symptoms and are found by accident during imaging tests done for other reasons. They are generally harmless and do not require treatment unless they start producing hormones or grow in size. Regular monitoring may be recommended to ensure that the adenoma remains stable over time. Understanding that this condition is usually benign can provide reassurance."\n}\n```', 'name': 'Writer', 'role': 'user'}], 'model': 'o1-mini'}
# ICD10_Labeler (to chat_manager):
#
# ```json
# {
#   "finding": "Adrenal Adenoma",
#   "ICD10_code": "D35.2",
#   "PFx": "An adrenal adenoma is a noncancerous growth that forms on one of your adrenal glands. These glands are small organs located above your kidneys and are responsible for producing hormones that help regulate various body functions, such as metabolism and stress response. In most cases, adrenal adenomas do not cause any symptoms and are found by accident during imaging tests done for other reasons. They are generally harmless and do not require treatment unless they start producing hormones or grow in size. Regular monitoring may be recommended to ensure that the adenoma remains stable over time. Understanding that this condition is usually benign can provide reassurance.",
#   "PFx_ICD10_code": "D35.2"
# }
# ```
#
# --------------------------------------------------------------------------------
#
# Next speaker: Doctor
#
# params={'messages': [{'content': '\n<Context>\nYou are a doctor tasked with evaluating medical accuracy of patient friendly explanations (PFx) of Incidental Findings\n</Context>\n<Prompt>\nPlease examine the PFx to determine medical accuracy in explaining Adrenal Adenoma\nAssure the explanation aligns with the ICD-10 code: D35.00\nExamine the ICD10_code and the PFx_ICD10_code to determine the accuracy of the PFx. If they are completely different, the response could be inaccurate depending on what the codes represent.\n\n- If the response is medically accurate, send the response to the readability_checker. \n- If not, send the response back to the writer agent with:\n  - **Brief reason** for inaccuracy\n  - **Specific missing or incorrect details**\n</Prompt>\n<Format>\n1. **Verdict:** ["ACCURATE - Send to Readability" / "INACCURATE - Revise"]\nIF REQUIRED\n2. **Reasoning:** [Short explanation]\n3. **Fixes:** [Concise revision suggestions]\nIF IT IS INACCURATE, YOUR OUTPUT MUST BEGIN WITH THE WORD INACCURATE\n</Format>\n', 'role': 'system'}, {'content': 'Please play your specified role in \n    generating a patient friendly explanation of an inicidental MRI finding.', 'name': 'chat_manager', 'role': 'user'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous growth that forms on one of your adrenal glands. These glands are small organs located above your kidneys and are responsible for producing hormones that help regulate various body functions, such as metabolism and stress response. In most cases, adrenal adenomas do not cause any symptoms and are found by accident during imaging tests done for other reasons. They are generally harmless and do not require treatment unless they start producing hormones or grow in size. Regular monitoring may be recommended to ensure that the adenoma remains stable over time. Understanding that this condition is usually benign can provide reassurance."\n}\n```', 'name': 'Writer', 'role': 'user'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous growth that forms on one of your adrenal glands. These glands are small organs located above your kidneys and are responsible for producing hormones that help regulate various body functions, such as metabolism and stress response. In most cases, adrenal adenomas do not cause any symptoms and are found by accident during imaging tests done for other reasons. They are generally harmless and do not require treatment unless they start producing hormones or grow in size. Regular monitoring may be recommended to ensure that the adenoma remains stable over time. Understanding that this condition is usually benign can provide reassurance.",\n  "PFx_ICD10_code": "D35.2"\n}\n```', 'name': 'ICD10_Labeler', 'role': 'user'}], 'model': 'o1-mini'}
# Doctor (to chat_manager):
#
# 1. **Verdict:** ACCURATE - Send to Readability
#
# --------------------------------------------------------------------------------
#
# Next speaker: Readability_Checker
#
# params={'messages': [{'content': '\n<Context>\nYou are an expert in the English language. You are familiar with the Flesch Reading Ease Score (FRES) metric to determine readability.\nHere is the FRES calculation: 206.835 - 1.015 × (total words ÷ total sentences) - 84.6 × (total syllables ÷ total words) \nHere is the FRES Scale:\n90 - 100 5th grade\n80 - 90\t6th grade\n70 - 80\t7th grade\n60 - 70\t8th & 9th \n50 - 60\t10th to 12th grade\n30 - 50\tCollege\n10 - 30\tCollege graduate\n0 - 10\tProfessional\n</Context>\n<Prompt>\nDetermine if the provided PFx matches the desired Flesch Reading Ease Score (FRES) 6th grade.\nOnly provide the writer with advice, do not give sample revisions.\n</Prompt>\n<Format>\n- If it does not match, return to the writer with:\n  - A **brief** reason why it doesn’t match.\n  - **Specific** changes needed to reach the desired level.\n- If it matches, say "All done!"\nIF IT DOES NOT MATCH, YOUR OUTPUT MUST BEGIN WITH: **NOT READABLE**\nIF IT IS IN THE DESIRED RANGE, SAY "All done!"\n</Format>\n', 'role': 'system'}, {'content': 'Please play your specified role in \n    generating a patient friendly explanation of an inicidental MRI finding.', 'name': 'chat_manager', 'role': 'user'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous growth that forms on one of your adrenal glands. These glands are small organs located above your kidneys and are responsible for producing hormones that help regulate various body functions, such as metabolism and stress response. In most cases, adrenal adenomas do not cause any symptoms and are found by accident during imaging tests done for other reasons. They are generally harmless and do not require treatment unless they start producing hormones or grow in size. Regular monitoring may be recommended to ensure that the adenoma remains stable over time. Understanding that this condition is usually benign can provide reassurance."\n}\n```', 'name': 'Writer', 'role': 'user'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous growth that forms on one of your adrenal glands. These glands are small organs located above your kidneys and are responsible for producing hormones that help regulate various body functions, such as metabolism and stress response. In most cases, adrenal adenomas do not cause any symptoms and are found by accident during imaging tests done for other reasons. They are generally harmless and do not require treatment unless they start producing hormones or grow in size. Regular monitoring may be recommended to ensure that the adenoma remains stable over time. Understanding that this condition is usually benign can provide reassurance.",\n  "PFx_ICD10_code": "D35.2"\n}\n```', 'name': 'ICD10_Labeler', 'role': 'user'}, {'content': '1. **Verdict:** ACCURATE - Send to Readability', 'name': 'Doctor', 'role': 'user'}], 'model': 'o1-mini'}
# Readability_Checker (to chat_manager):
#
# **NOT READABLE**
#
# The text is written at a much higher reading level than the desired 6th grade. To achieve the appropriate readability:
# - Use shorter, simpler sentences.
# - Choose more common and everyday words.
# - Reduce the number of syllables in each word.
#
# --------------------------------------------------------------------------------
#
# Next speaker: Writer
#
# params={'messages': [{'content': '\n\n<Prompt>\nPlease generate new <PFx> for the <Incidental Finding>\n\nOutput should be formatted as a json with the following attributes/fields: finding, ICD10_code, PFx\n\nAdditional Instructions:\n1. DO NOT SUGGEST FOLLOW UP STEPS WITH THE DOCTOR\n2. Maintain a formal, informative tone\n3. If you choose to utilize an anology, do not use more than one. Maint\n4. Please generate PFx at a 6th grade Flesch-Kincaid reading level.\n5. Please output PFx in 100 words or more\n\n</Prompt>\n\n<Incidental Finding> \nAdrenal Adenoma \n</Incidental Finding>  \n', 'role': 'system'}, {'content': 'Please play your specified role in \n    generating a patient friendly explanation of an inicidental MRI finding.', 'name': 'chat_manager', 'role': 'user'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous growth that forms on one of your adrenal glands. These glands are small organs located above your kidneys and are responsible for producing hormones that help regulate various body functions, such as metabolism and stress response. In most cases, adrenal adenomas do not cause any symptoms and are found by accident during imaging tests done for other reasons. They are generally harmless and do not require treatment unless they start producing hormones or grow in size. Regular monitoring may be recommended to ensure that the adenoma remains stable over time. Understanding that this condition is usually benign can provide reassurance."\n}\n```', 'role': 'assistant', 'name': 'Writer'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous growth that forms on one of your adrenal glands. These glands are small organs located above your kidneys and are responsible for producing hormones that help regulate various body functions, such as metabolism and stress response. In most cases, adrenal adenomas do not cause any symptoms and are found by accident during imaging tests done for other reasons. They are generally harmless and do not require treatment unless they start producing hormones or grow in size. Regular monitoring may be recommended to ensure that the adenoma remains stable over time. Understanding that this condition is usually benign can provide reassurance.",\n  "PFx_ICD10_code": "D35.2"\n}\n```', 'name': 'ICD10_Labeler', 'role': 'user'}, {'content': '1. **Verdict:** ACCURATE - Send to Readability', 'name': 'Doctor', 'role': 'user'}, {'content': '**NOT READABLE**\n\nThe text is written at a much higher reading level than the desired 6th grade. To achieve the appropriate readability:\n- Use shorter, simpler sentences.\n- Choose more common and everyday words.\n- Reduce the number of syllables in each word.', 'name': 'Readability_Checker', 'role': 'user'}], 'model': 'o1-mini'}
# Writer (to chat_manager):
#
# ```json
# {
#   "finding": "Adrenal Adenoma",
#   "ICD10_code": "D35.2",
#   "PFx": "An adrenal adenoma is a noncancerous lump that grows on one of your adrenal glands. These glands are small organs above your kidneys that make important hormones for your body. Most of the time, adrenal adenomas do not cause any problems and are found by chance during scans done for other reasons. They are usually harmless and do not need treatment unless they start making too many hormones or get bigger. Your doctor may want to check it regularly to make sure it stays the same. Knowing that this condition is usually not serious can help you feel better and reduce any worries you might have."
# }
# ```
#
# --------------------------------------------------------------------------------
#
# Next speaker: ICD10_Labeler
#
# params={'messages': [{'content': '"\n<Context>\nYou are a medical professional knowledgable in ICD10 codes and their corresponding disorders. You\'re tasked with labelling a pateint friendly explanation with the ICD10 code of the described incidental finding.\n</Context>\n<Prompt>\nPlease label the provided response with the ICD10 code of the described incidental finding.\nAdd the following field to the provided response with the ICD10 code you identified: PFx_ICD10_code\nThis is your sole job, do not do anything else.\n</Prompt>\n<Format>\nOutput should be formatted as a json with the following attributes/fields: finding, ICD10_code, PFx, PFx_ICD10_code\n</Format>\n', 'role': 'system'}, {'content': 'Please play your specified role in \n    generating a patient friendly explanation of an inicidental MRI finding.', 'name': 'chat_manager', 'role': 'user'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous growth that forms on one of your adrenal glands. These glands are small organs located above your kidneys and are responsible for producing hormones that help regulate various body functions, such as metabolism and stress response. In most cases, adrenal adenomas do not cause any symptoms and are found by accident during imaging tests done for other reasons. They are generally harmless and do not require treatment unless they start producing hormones or grow in size. Regular monitoring may be recommended to ensure that the adenoma remains stable over time. Understanding that this condition is usually benign can provide reassurance."\n}\n```', 'name': 'Writer', 'role': 'user'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous growth that forms on one of your adrenal glands. These glands are small organs located above your kidneys and are responsible for producing hormones that help regulate various body functions, such as metabolism and stress response. In most cases, adrenal adenomas do not cause any symptoms and are found by accident during imaging tests done for other reasons. They are generally harmless and do not require treatment unless they start producing hormones or grow in size. Regular monitoring may be recommended to ensure that the adenoma remains stable over time. Understanding that this condition is usually benign can provide reassurance.",\n  "PFx_ICD10_code": "D35.2"\n}\n```', 'role': 'assistant', 'name': 'ICD10_Labeler'}, {'content': '1. **Verdict:** ACCURATE - Send to Readability', 'name': 'Doctor', 'role': 'user'}, {'content': '**NOT READABLE**\n\nThe text is written at a much higher reading level than the desired 6th grade. To achieve the appropriate readability:\n- Use shorter, simpler sentences.\n- Choose more common and everyday words.\n- Reduce the number of syllables in each word.', 'name': 'Readability_Checker', 'role': 'user'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous lump that grows on one of your adrenal glands. These glands are small organs above your kidneys that make important hormones for your body. Most of the time, adrenal adenomas do not cause any problems and are found by chance during scans done for other reasons. They are usually harmless and do not need treatment unless they start making too many hormones or get bigger. Your doctor may want to check it regularly to make sure it stays the same. Knowing that this condition is usually not serious can help you feel better and reduce any worries you might have."\n}\n```', 'name': 'Writer', 'role': 'user'}], 'model': 'o1-mini'}
# ICD10_Labeler (to chat_manager):
#
# ```json
# {
#   "finding": "Adrenal Adenoma",
#   "ICD10_code": "D35.2",
#   "PFx": "An adrenal adenoma is a noncancerous lump that grows on one of your adrenal glands. These glands are small organs above your kidneys that make important hormones for your body. Most of the time, adrenal adenomas do not cause any problems and are found by chance during scans done for other reasons. They are usually harmless and do not need treatment unless they start making too many hormones or get bigger. Your doctor may want to check it regularly to make sure it stays the same. Knowing that this condition is usually not serious can help you feel better and reduce any worries you might have.",
#   "PFx_ICD10_code": "D35.2"
# }
# ```
#
# --------------------------------------------------------------------------------
#
# Next speaker: Doctor
#
# params={'messages': [{'content': '\n<Context>\nYou are a doctor tasked with evaluating medical accuracy of patient friendly explanations (PFx) of Incidental Findings\n</Context>\n<Prompt>\nPlease examine the PFx to determine medical accuracy in explaining Adrenal Adenoma\nAssure the explanation aligns with the ICD-10 code: D35.00\nExamine the ICD10_code and the PFx_ICD10_code to determine the accuracy of the PFx. If they are completely different, the response could be inaccurate depending on what the codes represent.\n\n- If the response is medically accurate, send the response to the readability_checker. \n- If not, send the response back to the writer agent with:\n  - **Brief reason** for inaccuracy\n  - **Specific missing or incorrect details**\n</Prompt>\n<Format>\n1. **Verdict:** ["ACCURATE - Send to Readability" / "INACCURATE - Revise"]\nIF REQUIRED\n2. **Reasoning:** [Short explanation]\n3. **Fixes:** [Concise revision suggestions]\nIF IT IS INACCURATE, YOUR OUTPUT MUST BEGIN WITH THE WORD INACCURATE\n</Format>\n', 'role': 'system'}, {'content': 'Please play your specified role in \n    generating a patient friendly explanation of an inicidental MRI finding.', 'name': 'chat_manager', 'role': 'user'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous growth that forms on one of your adrenal glands. These glands are small organs located above your kidneys and are responsible for producing hormones that help regulate various body functions, such as metabolism and stress response. In most cases, adrenal adenomas do not cause any symptoms and are found by accident during imaging tests done for other reasons. They are generally harmless and do not require treatment unless they start producing hormones or grow in size. Regular monitoring may be recommended to ensure that the adenoma remains stable over time. Understanding that this condition is usually benign can provide reassurance."\n}\n```', 'name': 'Writer', 'role': 'user'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous growth that forms on one of your adrenal glands. These glands are small organs located above your kidneys and are responsible for producing hormones that help regulate various body functions, such as metabolism and stress response. In most cases, adrenal adenomas do not cause any symptoms and are found by accident during imaging tests done for other reasons. They are generally harmless and do not require treatment unless they start producing hormones or grow in size. Regular monitoring may be recommended to ensure that the adenoma remains stable over time. Understanding that this condition is usually benign can provide reassurance.",\n  "PFx_ICD10_code": "D35.2"\n}\n```', 'name': 'ICD10_Labeler', 'role': 'user'}, {'content': '1. **Verdict:** ACCURATE - Send to Readability', 'role': 'assistant', 'name': 'Doctor'}, {'content': '**NOT READABLE**\n\nThe text is written at a much higher reading level than the desired 6th grade. To achieve the appropriate readability:\n- Use shorter, simpler sentences.\n- Choose more common and everyday words.\n- Reduce the number of syllables in each word.', 'name': 'Readability_Checker', 'role': 'user'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous lump that grows on one of your adrenal glands. These glands are small organs above your kidneys that make important hormones for your body. Most of the time, adrenal adenomas do not cause any problems and are found by chance during scans done for other reasons. They are usually harmless and do not need treatment unless they start making too many hormones or get bigger. Your doctor may want to check it regularly to make sure it stays the same. Knowing that this condition is usually not serious can help you feel better and reduce any worr ...
# Doctor (to chat_manager):
#
# 1. **Verdict:** ACCURATE - Send to Readability
#
# --------------------------------------------------------------------------------
#
# Next speaker: Readability_Checker
#
# params={'messages': [{'content': '\n<Context>\nYou are an expert in the English language. You are familiar with the Flesch Reading Ease Score (FRES) metric to determine readability.\nHere is the FRES calculation: 206.835 - 1.015 × (total words ÷ total sentences) - 84.6 × (total syllables ÷ total words) \nHere is the FRES Scale:\n90 - 100 5th grade\n80 - 90\t6th grade\n70 - 80\t7th grade\n60 - 70\t8th & 9th \n50 - 60\t10th to 12th grade\n30 - 50\tCollege\n10 - 30\tCollege graduate\n0 - 10\tProfessional\n</Context>\n<Prompt>\nDetermine if the provided PFx matches the desired Flesch Reading Ease Score (FRES) 6th grade.\nOnly provide the writer with advice, do not give sample revisions.\n</Prompt>\n<Format>\n- If it does not match, return to the writer with:\n  - A **brief** reason why it doesn’t match.\n  - **Specific** changes needed to reach the desired level.\n- If it matches, say "All done!"\nIF IT DOES NOT MATCH, YOUR OUTPUT MUST BEGIN WITH: **NOT READABLE**\nIF IT IS IN THE DESIRED RANGE, SAY "All done!"\n</Format>\n', 'role': 'system'}, {'content': 'Please play your specified role in \n    generating a patient friendly explanation of an inicidental MRI finding.', 'name': 'chat_manager', 'role': 'user'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous growth that forms on one of your adrenal glands. These glands are small organs located above your kidneys and are responsible for producing hormones that help regulate various body functions, such as metabolism and stress response. In most cases, adrenal adenomas do not cause any symptoms and are found by accident during imaging tests done for other reasons. They are generally harmless and do not require treatment unless they start producing hormones or grow in size. Regular monitoring may be recommended to ensure that the adenoma remains stable over time. Understanding that this condition is usually benign can provide reassurance."\n}\n```', 'name': 'Writer', 'role': 'user'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous growth that forms on one of your adrenal glands. These glands are small organs located above your kidneys and are responsible for producing hormones that help regulate various body functions, such as metabolism and stress response. In most cases, adrenal adenomas do not cause any symptoms and are found by accident during imaging tests done for other reasons. They are generally harmless and do not require treatment unless they start producing hormones or grow in size. Regular monitoring may be recommended to ensure that the adenoma remains stable over time. Understanding that this condition is usually benign can provide reassurance.",\n  "PFx_ICD10_code": "D35.2"\n}\n```', 'name': 'ICD10_Labeler', 'role': 'user'}, {'content': '1. **Verdict:** ACCURATE - Send to Readability', 'name': 'Doctor', 'role': 'user'}, {'content': '**NOT READABLE**\n\nThe text is written at a much higher reading level than the desired 6th grade. To achieve the appropriate readability:\n- Use shorter, simpler sentences.\n- Choose more common and everyday words.\n- Reduce the number of syllables in each word.', 'role': 'assistant', 'name': 'Readability_Checker'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous lump that grows on one of your adrenal glands. These glands are small organs above your kidneys that make important hormones for your body. Most of the time, adrenal adenomas do not cause any problems and are found by chance during scans done for other reasons. They are usually harmless and do not need treatment unless they start making too many hormones or get bigger. Your doctor may want to check it regularly to make sure it stays the same. Knowing that this condition is usually not serious can help you feel better and reduce any worr ...
# Readability_Checker (to chat_manager):
#
# **NOT READABLE**
#
# The text is still above the 6th-grade reading level. To improve readability:
# - Break longer sentences into shorter ones.
# - Use simpler and more common words.
# - Avoid or simplify medical terms.
#
# --------------------------------------------------------------------------------
#
# Next speaker: Writer
#
# params={'messages': [{'content': '\n\n<Prompt>\nPlease generate new <PFx> for the <Incidental Finding>\n\nOutput should be formatted as a json with the following attributes/fields: finding, ICD10_code, PFx\n\nAdditional Instructions:\n1. DO NOT SUGGEST FOLLOW UP STEPS WITH THE DOCTOR\n2. Maintain a formal, informative tone\n3. If you choose to utilize an anology, do not use more than one. Maint\n4. Please generate PFx at a 6th grade Flesch-Kincaid reading level.\n5. Please output PFx in 100 words or more\n\n</Prompt>\n\n<Incidental Finding> \nAdrenal Adenoma \n</Incidental Finding>  \n', 'role': 'system'}, {'content': 'Please play your specified role in \n    generating a patient friendly explanation of an inicidental MRI finding.', 'name': 'chat_manager', 'role': 'user'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous growth that forms on one of your adrenal glands. These glands are small organs located above your kidneys and are responsible for producing hormones that help regulate various body functions, such as metabolism and stress response. In most cases, adrenal adenomas do not cause any symptoms and are found by accident during imaging tests done for other reasons. They are generally harmless and do not require treatment unless they start producing hormones or grow in size. Regular monitoring may be recommended to ensure that the adenoma remains stable over time. Understanding that this condition is usually benign can provide reassurance."\n}\n```', 'role': 'assistant', 'name': 'Writer'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous growth that forms on one of your adrenal glands. These glands are small organs located above your kidneys and are responsible for producing hormones that help regulate various body functions, such as metabolism and stress response. In most cases, adrenal adenomas do not cause any symptoms and are found by accident during imaging tests done for other reasons. They are generally harmless and do not require treatment unless they start producing hormones or grow in size. Regular monitoring may be recommended to ensure that the adenoma remains stable over time. Understanding that this condition is usually benign can provide reassurance.",\n  "PFx_ICD10_code": "D35.2"\n}\n```', 'name': 'ICD10_Labeler', 'role': 'user'}, {'content': '1. **Verdict:** ACCURATE - Send to Readability', 'name': 'Doctor', 'role': 'user'}, {'content': '**NOT READABLE**\n\nThe text is written at a much higher reading level than the desired 6th grade. To achieve the appropriate readability:\n- Use shorter, simpler sentences.\n- Choose more common and everyday words.\n- Reduce the number of syllables in each word.', 'name': 'Readability_Checker', 'role': 'user'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous lump that grows on one of your adrenal glands. These glands are small organs above your kidneys that make important hormones for your body. Most of the time, adrenal adenomas do not cause any problems and are found by chance during scans done for other reasons. They are usually harmless and do not need treatment unless they start making too many hormones or get bigger. Your doctor may want to check it regularly to make sure it stays the same. Knowing that this condition is usually not serious can help you feel better and reduce any worries you might have."\n}\n```', 'role': 'assistant', 'name': 'Writer'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous lump that grows on one of your adrenal glands. These glands are small organs above your kidneys that make important hormones for your body. Most of the time, adrenal adenomas do not cause any problems and are found by chance during scans don ...
# Writer (to chat_manager):
#
# ```json
# {
#   "finding": "Adrenal Adenoma",
#   "ICD10_code": "D35.2",
#   "PFx": "An adrenal adenoma is a lump that grows on one of your adrenal glands. These glands are small organs above your kidneys. They make important chemicals that help your body work properly. Most of the time, adrenal adenomas do not cause any problems. They are found by accident during scans done for other reasons. These lumps are usually not dangerous and do not need treatment unless they start making too many chemicals or get bigger. Your doctor might want to check it regularly to make sure it stays the same. Knowing that this condition is usually not serious can help you feel better and reduce any worries you might have."
# }
# ```
#
# --------------------------------------------------------------------------------
#
# Next speaker: ICD10_Labeler
#
# params={'messages': [{'content': '"\n<Context>\nYou are a medical professional knowledgable in ICD10 codes and their corresponding disorders. You\'re tasked with labelling a pateint friendly explanation with the ICD10 code of the described incidental finding.\n</Context>\n<Prompt>\nPlease label the provided response with the ICD10 code of the described incidental finding.\nAdd the following field to the provided response with the ICD10 code you identified: PFx_ICD10_code\nThis is your sole job, do not do anything else.\n</Prompt>\n<Format>\nOutput should be formatted as a json with the following attributes/fields: finding, ICD10_code, PFx, PFx_ICD10_code\n</Format>\n', 'role': 'system'}, {'content': 'Please play your specified role in \n    generating a patient friendly explanation of an inicidental MRI finding.', 'name': 'chat_manager', 'role': 'user'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous growth that forms on one of your adrenal glands. These glands are small organs located above your kidneys and are responsible for producing hormones that help regulate various body functions, such as metabolism and stress response. In most cases, adrenal adenomas do not cause any symptoms and are found by accident during imaging tests done for other reasons. They are generally harmless and do not require treatment unless they start producing hormones or grow in size. Regular monitoring may be recommended to ensure that the adenoma remains stable over time. Understanding that this condition is usually benign can provide reassurance."\n}\n```', 'name': 'Writer', 'role': 'user'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous growth that forms on one of your adrenal glands. These glands are small organs located above your kidneys and are responsible for producing hormones that help regulate various body functions, such as metabolism and stress response. In most cases, adrenal adenomas do not cause any symptoms and are found by accident during imaging tests done for other reasons. They are generally harmless and do not require treatment unless they start producing hormones or grow in size. Regular monitoring may be recommended to ensure that the adenoma remains stable over time. Understanding that this condition is usually benign can provide reassurance.",\n  "PFx_ICD10_code": "D35.2"\n}\n```', 'role': 'assistant', 'name': 'ICD10_Labeler'}, {'content': '1. **Verdict:** ACCURATE - Send to Readability', 'name': 'Doctor', 'role': 'user'}, {'content': '**NOT READABLE**\n\nThe text is written at a much higher reading level than the desired 6th grade. To achieve the appropriate readability:\n- Use shorter, simpler sentences.\n- Choose more common and everyday words.\n- Reduce the number of syllables in each word.', 'name': 'Readability_Checker', 'role': 'user'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous lump that grows on one of your adrenal glands. These glands are small organs above your kidneys that make important hormones for your body. Most of the time, adrenal adenomas do not cause any problems and are found by chance during scans done for other reasons. They are usually harmless and do not need treatment unless they start making too many hormones or get bigger. Your doctor may want to check it regularly to make sure it stays the same. Knowing that this condition is usually not serious can help you feel better and reduce any worries you might have."\n}\n```', 'name': 'Writer', 'role': 'user'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous lump that grows on one of your adrenal glands. These glands are small organs above your kidneys that make important hormones for your body. Most of the time, adren ...
# ICD10_Labeler (to chat_manager):
#
# ```json
# {
#   "finding": "Adrenal Adenoma",
#   "ICD10_code": "D35.2",
#   "PFx": "An adrenal adenoma is a lump that grows on one of your adrenal glands. These glands are small organs above your kidneys. They make important chemicals that help your body work properly. Most of the time, adrenal adenomas do not cause any problems. They are found by accident during scans done for other reasons. These lumps are usually not dangerous and do not need treatment unless they start making too many chemicals or get bigger. Your doctor might want to check it regularly to make sure it stays the same. Knowing that this condition is usually not serious can help you feel better and reduce any worries you might have.",
#   "PFx_ICD10_code": "D35.2"
# }
# ```
#
# --------------------------------------------------------------------------------
#
# Next speaker: Doctor
#
# params={'messages': [{'content': '\n<Context>\nYou are a doctor tasked with evaluating medical accuracy of patient friendly explanations (PFx) of Incidental Findings\n</Context>\n<Prompt>\nPlease examine the PFx to determine medical accuracy in explaining Adrenal Adenoma\nAssure the explanation aligns with the ICD-10 code: D35.00\nExamine the ICD10_code and the PFx_ICD10_code to determine the accuracy of the PFx. If they are completely different, the response could be inaccurate depending on what the codes represent.\n\n- If the response is medically accurate, send the response to the readability_checker. \n- If not, send the response back to the writer agent with:\n  - **Brief reason** for inaccuracy\n  - **Specific missing or incorrect details**\n</Prompt>\n<Format>\n1. **Verdict:** ["ACCURATE - Send to Readability" / "INACCURATE - Revise"]\nIF REQUIRED\n2. **Reasoning:** [Short explanation]\n3. **Fixes:** [Concise revision suggestions]\nIF IT IS INACCURATE, YOUR OUTPUT MUST BEGIN WITH THE WORD INACCURATE\n</Format>\n', 'role': 'system'}, {'content': 'Please play your specified role in \n    generating a patient friendly explanation of an inicidental MRI finding.', 'name': 'chat_manager', 'role': 'user'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous growth that forms on one of your adrenal glands. These glands are small organs located above your kidneys and are responsible for producing hormones that help regulate various body functions, such as metabolism and stress response. In most cases, adrenal adenomas do not cause any symptoms and are found by accident during imaging tests done for other reasons. They are generally harmless and do not require treatment unless they start producing hormones or grow in size. Regular monitoring may be recommended to ensure that the adenoma remains stable over time. Understanding that this condition is usually benign can provide reassurance."\n}\n```', 'name': 'Writer', 'role': 'user'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous growth that forms on one of your adrenal glands. These glands are small organs located above your kidneys and are responsible for producing hormones that help regulate various body functions, such as metabolism and stress response. In most cases, adrenal adenomas do not cause any symptoms and are found by accident during imaging tests done for other reasons. They are generally harmless and do not require treatment unless they start producing hormones or grow in size. Regular monitoring may be recommended to ensure that the adenoma remains stable over time. Understanding that this condition is usually benign can provide reassurance.",\n  "PFx_ICD10_code": "D35.2"\n}\n```', 'name': 'ICD10_Labeler', 'role': 'user'}, {'content': '1. **Verdict:** ACCURATE - Send to Readability', 'role': 'assistant', 'name': 'Doctor'}, {'content': '**NOT READABLE**\n\nThe text is written at a much higher reading level than the desired 6th grade. To achieve the appropriate readability:\n- Use shorter, simpler sentences.\n- Choose more common and everyday words.\n- Reduce the number of syllables in each word.', 'name': 'Readability_Checker', 'role': 'user'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous lump that grows on one of your adrenal glands. These glands are small organs above your kidneys that make important hormones for your body. Most of the time, adrenal adenomas do not cause any problems and are found by chance during scans done for other reasons. They are usually harmless and do not need treatment unless they start making too many hormones or get bigger. Your doctor may want to check it regularly to make sure it stays the same. Knowing that this condition is usually not serious can help you feel better and reduce any worr ...
# Doctor (to chat_manager):
#
# **INACCURATE - Revise**
#
# 2. **Reasoning:** The ICD-10 code D35.2 does not correspond to an Adrenal Adenoma. The correct ICD-10 code for Adrenal Adenoma is D35.31.
#
# 3. **Fixes:**
# - Update the `ICD10_code` and `PFx_ICD10_code` to **D35.31** to accurately represent Adrenal Adenoma.
# - Ensure that any references to the ICD-10 code within the explanation are consistent with the correct code.
#
# --------------------------------------------------------------------------------
#
# Next speaker: Writer
#
# params={'messages': [{'content': '\n\n<Prompt>\nPlease generate new <PFx> for the <Incidental Finding>\n\nOutput should be formatted as a json with the following attributes/fields: finding, ICD10_code, PFx\n\nAdditional Instructions:\n1. DO NOT SUGGEST FOLLOW UP STEPS WITH THE DOCTOR\n2. Maintain a formal, informative tone\n3. If you choose to utilize an anology, do not use more than one. Maint\n4. Please generate PFx at a 6th grade Flesch-Kincaid reading level.\n5. Please output PFx in 100 words or more\n\n</Prompt>\n\n<Incidental Finding> \nAdrenal Adenoma \n</Incidental Finding>  \n', 'role': 'system'}, {'content': 'Please play your specified role in \n    generating a patient friendly explanation of an inicidental MRI finding.', 'name': 'chat_manager', 'role': 'user'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous growth that forms on one of your adrenal glands. These glands are small organs located above your kidneys and are responsible for producing hormones that help regulate various body functions, such as metabolism and stress response. In most cases, adrenal adenomas do not cause any symptoms and are found by accident during imaging tests done for other reasons. They are generally harmless and do not require treatment unless they start producing hormones or grow in size. Regular monitoring may be recommended to ensure that the adenoma remains stable over time. Understanding that this condition is usually benign can provide reassurance."\n}\n```', 'role': 'assistant', 'name': 'Writer'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous growth that forms on one of your adrenal glands. These glands are small organs located above your kidneys and are responsible for producing hormones that help regulate various body functions, such as metabolism and stress response. In most cases, adrenal adenomas do not cause any symptoms and are found by accident during imaging tests done for other reasons. They are generally harmless and do not require treatment unless they start producing hormones or grow in size. Regular monitoring may be recommended to ensure that the adenoma remains stable over time. Understanding that this condition is usually benign can provide reassurance.",\n  "PFx_ICD10_code": "D35.2"\n}\n```', 'name': 'ICD10_Labeler', 'role': 'user'}, {'content': '1. **Verdict:** ACCURATE - Send to Readability', 'name': 'Doctor', 'role': 'user'}, {'content': '**NOT READABLE**\n\nThe text is written at a much higher reading level than the desired 6th grade. To achieve the appropriate readability:\n- Use shorter, simpler sentences.\n- Choose more common and everyday words.\n- Reduce the number of syllables in each word.', 'name': 'Readability_Checker', 'role': 'user'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous lump that grows on one of your adrenal glands. These glands are small organs above your kidneys that make important hormones for your body. Most of the time, adrenal adenomas do not cause any problems and are found by chance during scans done for other reasons. They are usually harmless and do not need treatment unless they start making too many hormones or get bigger. Your doctor may want to check it regularly to make sure it stays the same. Knowing that this condition is usually not serious can help you feel better and reduce any worries you might have."\n}\n```', 'role': 'assistant', 'name': 'Writer'}, {'content': '```json\n{\n  "finding": "Adrenal Adenoma",\n  "ICD10_code": "D35.2",\n  "PFx": "An adrenal adenoma is a noncancerous lump that grows on one of your adrenal glands. These glands are small organs above your kidneys that make important hormones for your body. Most of the time, adrenal adenomas do not cause any problems and are found by chance during scans don ...
# Writer (to chat_manager):
#
# ```json
# {
#   "finding": "Adrenal Adenoma",
#   "ICD10_code": "D35.31",
#   "PFx": "An adrenal adenoma is a lump that grows on one of your adrenal glands. These glands are small organs above your kidneys. They make important chemicals that help your body work properly. Most of the time, adrenal adenomas do not cause any problems. They are found by accident during scans done for other reasons. These lumps are usually not dangerous and do not need treatment unless they start making too many chemicals or get bigger. Your doctor might want to check it regularly to make sure it stays the same. Knowing that this condition is usually not serious can help you feel better and reduce any worries you might have.",
#   "PFx_ICD10_code": "D35.31"
# }
# ```
#
# --------------------------------------------------------------------------------
#
# Next speaker: ICD10_Labeler
#
# ...
#   "PFx_ICD10_code": "R93.4"
# }
# ```
#
# --------------------------------------------------------------------------------
#
# Next speaker: ICD10_Labeler
#
# params={'messages': [{'content': '"\n<Context>\nYou are a medical professional knowledgable in ICD10 codes and their corresponding disorders. You\'re tasked with labelling a pateint friendly explanation with the ICD10 code of the described incidental finding.\n</Context>\n<Prompt>\nPlease label the provided response with the ICD10 code of the described incidental finding.\nAdd the following field to the provided response with the ICD10 code you identified: PFx_ICD10_code\nThis is your sole job, do not do anything else.\n</Prompt>\n<Format>\nOutput should be formatted as a json with the following attributes/fields: finding, ICD10_code, PFx, PFx_ICD10_code\n</Format>\n', 'role': 'system'}, {'content': 'Please play your specified role in \n    generating a patient friendly explanation of an inicidental MRI finding.', 'name': 'chat_manager', 'role': 'user'}, {'content': '```json\n{\n  "finding": "Bladder Cyst",\n  "ICD10_code": "N32.9",\n  "PFx": "A bladder cyst is a small, fluid-filled sac that forms inside the bladder. It is usually discovered by chance during imaging tests like an MRI. Most bladder cysts are benign, meaning they are not cancerous, and they typically do not cause any symptoms. In many cases, bladder cysts do not require treatment and do not lead to any health problems. Think of it as a tiny water balloon inside the bladder that doesn\'t interfere with its normal functions. Regular monitoring through routine health check-ups is often sufficient to ensure that the cyst does not change or cause issues over time."\n}\n```', 'name': 'Writer', 'role': 'user'}, {'content': '```json\n{\n  "finding": "Bladder Cyst",\n  "ICD10_code": "N32.9",\n  "PFx": "A bladder cyst is a small, fluid-filled sac that forms inside the bladder. It is usually discovered by chance during imaging tests like an MRI. Most bladder cysts are benign, meaning they are not cancerous, and they typically do not cause any symptoms. In many cases, bladder cysts do not require treatment and do not lead to any health problems. Think of it as a tiny water balloon inside the bladder that doesn\'t interfere with its normal functions. Regular monitoring through routine health check-ups is often sufficient to ensure that the cyst does not change or cause issues over time.",\n  "PFx_ICD10_code": "N32.9"\n}\n```', 'role': 'assistant', 'name': 'ICD10_Labeler'}, {'content': 'INACCURATE - Revise\n\n**Reasoning:** The patient-friendly explanation (PFx) uses ICD-10 code **N32.9**, which refers to an "Unspecified bladder disorder." However, the intended ICD-10 code for an incidental finding on diagnostic imaging is **R93.4** ("Abnormal findings on diagnostic imaging of urinary system and pelvic region"). This discrepancy means the PFx may inaccurately represent the nature of the finding.\n\n**Fixes:**\n1. **Update ICD-10 Codes:** Change both the `ICD10_code` and `PFx_ICD10_code` from **N32.9** to **R93.4** to accurately reflect that the bladder cyst was an incidental finding on imaging.\n2. **Revise Explanation:** Modify the PFx to emphasize that the bladder cyst was discovered incidentally during imaging tests and is not indicative of a diagnosed bladder disorder. For example:\n   \n   > "A bladder cyst is a small, fluid-filled sac that was unexpectedly found inside the bladder during an MRI scan. Most bladder cysts are benign, meaning they are not cancerous, and typically do not cause any symptoms. In many cases, bladder cysts discovered in this way do not require treatment and do not lead to any health problems. Think of it as a tiny water balloon inside the bladder that doesn\'t interfere with its normal functions. Regular monitoring through routine health check-ups is often sufficient to ensure that the cyst does not change or cause issues over time."', 'name': 'Doctor', 'role': 'user'}, {'content': '```json\n{\n  "finding": "Bladder Cyst",\n  "ICD10_code": "R93.4",\n  "PFx": "A bladder cyst is a small, fluid-filled sac that was unexpectedly found inside the blad ...
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[28], line 49
#      38 groupchat = autogen.GroupChat(
#      39     agents = [writer, icd10_labeler, doctor, readability_checker],
#      40     messages = [],
#      41     max_round = 20,
#      42     speaker_selection_method = state_transition,
#      43 )
#      45 manager = autogen.GroupChatManager(
#      46     groupchat = groupchat, llm_config = llm_config,
#      47 )
# ---> 49 groupchat_result = manager.initiate_chat(manager, message = """Please play your specified role in
#      50 generating a patient friendly explanation of an inicidental MRI finding.""")
#      52 chat = extract_json_gpt4o(groupchat)
#      54 results.loc[i] = {
#      55     "finding": row['Incidental_Finding'],
#      56     "ICD10_code": row['ICD10_code'],
#      57     "PFx": chat.get("PFx", ""),
#      58     "PFx_ICD10_code": chat.get("PFx_ICD10_code", "")
#      59 }
#
# File ~\VS Code Projects\Science Research\jh_pfx\jh_venv\Lib\site-packages\autogen\agentchat\conversable_agent.py:1500, in ConversableAgent.initiate_chat(self, recipient, clear_history, silent, cache, max_turns, summary_method, summary_args, message, **kwargs)
#    1498     else:
#    1499         msg2send = self.generate_init_message(message, **kwargs)
# -> 1500     self.send(msg2send, recipient, silent=silent)
#    1501 summary = self._summarize_chat(
#    1502     summary_method,
#    1503     summary_args,
#    1504     recipient,
#    1505     cache=cache,
#    1506 )
#    1507 for agent in [self, recipient]:
#
# File ~\VS Code Projects\Science Research\jh_pfx\jh_venv\Lib\site-packages\autogen\agentchat\conversable_agent.py:1192, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#    1190 valid = self._append_oai_message(message, "assistant", recipient, is_sending=True)
#    1191 if valid:
# -> 1192     recipient.receive(message, self, request_reply, silent)
#    1193 else:
#    1194     raise ValueError(
#    1195         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#    1196     )
#
# File ~\VS Code Projects\Science Research\jh_pfx\jh_venv\Lib\site-packages\autogen\agentchat\conversable_agent.py:1300, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#    1298 if request_reply is False or (request_reply is None and self.reply_at_receive[sender] is False):
#    1299     return
# -> 1300 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#    1301 if reply is not None:
#    1302     self.send(reply, sender, silent=silent)
#
# File ~\VS Code Projects\Science Research\jh_pfx\jh_venv\Lib\site-packages\autogen\agentchat\conversable_agent.py:2433, in ConversableAgent.generate_reply(self, messages, sender, **kwargs)
#    2431     continue
#    2432 if self._match_trigger(reply_func_tuple["trigger"], sender):
# -> 2433     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    2434     if logging_enabled():
#    2435         log_event(
#    2436             self,
#    2437             "reply_func_executed",
#    (...)
#    2441             reply=reply,
#    2442         )
#
# File ~\VS Code Projects\Science Research\jh_pfx\jh_venv\Lib\site-packages\autogen\agentchat\groupchat.py:1188, in GroupChatManager.run_chat(self, messages, sender, config)
#    1186         iostream.send(GroupChatRunChatMessage(speaker=speaker, silent=silent))
#    1187     # let the speaker speak
# -> 1188     reply = speaker.generate_reply(sender=self)
#    1189 except KeyboardInterrupt:
#    1190     # let the admin agent speak if interrupted
#    1191     if groupchat.admin_name in groupchat.agent_names:
#    1192         # admin agent is one of the participants
#
# File ~\VS Code Projects\Science Research\jh_pfx\jh_venv\Lib\site-packages\autogen\agentchat\conversable_agent.py:2433, in ConversableAgent.generate_reply(self, messages, sender, **kwargs)
#    2431     continue
#    2432 if self._match_trigger(reply_func_tuple["trigger"], sender):
# -> 2433     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    2434     if logging_enabled():
#    2435         log_event(
#    2436             self,
#    2437             "reply_func_executed",
#    (...)
#    2441             reply=reply,
#    2442         )
#
# File ~\VS Code Projects\Science Research\jh_pfx\jh_venv\Lib\site-packages\autogen\agentchat\conversable_agent.py:1818, in ConversableAgent.generate_oai_reply(self, messages, sender, config)
#    1816 if messages is None:
#    1817     messages = self._oai_messages[sender]
# -> 1818 extracted_response = self._generate_oai_reply_from_client(
#    1819     client, self._oai_system_message + messages, self.client_cache
#    1820 )
#    1821 return (False, None) if extracted_response is None else (True, extracted_response)
#
# File ~\VS Code Projects\Science Research\jh_pfx\jh_venv\Lib\site-packages\autogen\agentchat\conversable_agent.py:1837, in ConversableAgent._generate_oai_reply_from_client(self, llm_client, messages, cache)
#    1834         all_messages.append(message)
#    1836 # TODO: #1143 handle token limit exceeded error
# -> 1837 response = llm_client.create(
#    1838     context=messages[-1].pop("context", None),
#    1839     messages=all_messages,
#    1840     cache=cache,
#    1841     agent=self,
#    1842 )
#    1843 extracted_response = llm_client.extract_text_or_completion_object(response)[0]
#    1845 if extracted_response is None:
#
# File ~\VS Code Projects\Science Research\jh_pfx\jh_venv\Lib\site-packages\autogen\oai\client.py:1033, in OpenAIWrapper.create(self, **config)
#    1031 try:
#    1032     request_ts = get_current_ts()
# -> 1033     response = client.create(params)
#    1034 except APITimeoutError as err:
#    1035     logger.debug(f"config {i} timed out", exc_info=True)
#
# File ~\VS Code Projects\Science Research\jh_pfx\jh_venv\Lib\site-packages\autogen\oai\client.py:531, in OpenAIClient.create(self, params)
#     529     self._process_reasoning_model_params(params)
#     530 params["stream"] = False
# --> 531 response = create_or_parse(**params)
#     532 # remove the system_message from the response and add it in the prompt at the start.
#     533 if is_o1:
#
# File ~\VS Code Projects\Science Research\jh_pfx\jh_venv\Lib\site-packages\autogen\oai\client.py:360, in OpenAIClient._handle_openai_bad_request_error.<locals>.wrapper(*args, **kwargs)
#     358 try:
#     359     kwargs = OpenAIClient._patch_messages_for_deepseek_reasoner(**kwargs)
# --> 360     return func(*args, **kwargs)
#     361 except openai.BadRequestError as e:
#     362     response_json = e.response.json()
#
# File ~\VS Code Projects\Science Research\jh_pfx\jh_venv\Lib\site-packages\openai\_utils\_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File ~\VS Code Projects\Science Research\jh_pfx\jh_venv\Lib\site-packages\openai\resources\chat\completions.py:850, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     808 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     809 def create(
#     810     self,
#    (...)
#     847     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     848 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     849     validate_response_format(response_format)
# --> 850     return self._post(
#     851         "/chat/completions",
#     852         body=maybe_transform(
#     853             {
#     854                 "messages": messages,
#     855                 "model": model,
#     856                 "audio": audio,
#     857                 "frequency_penalty": frequency_penalty,
#     858                 "function_call": function_call,
#     859                 "functions": functions,
#     860                 "logit_bias": logit_bias,
#     861                 "logprobs": logprobs,
#     862                 "max_completion_tokens": max_completion_tokens,
#     863                 "max_tokens": max_tokens,
#     864                 "metadata": metadata,
#     865                 "modalities": modalities,
#     866                 "n": n,
#     867                 "parallel_tool_calls": parallel_tool_calls,
#     868                 "prediction": prediction,
#     869                 "presence_penalty": presence_penalty,
#     870                 "reasoning_effort": reasoning_effort,
#     871                 "response_format": response_format,
#     872                 "seed": seed,
#     873                 "service_tier": service_tier,
#     874                 "stop": stop,
#     875                 "store": store,
#     876                 "stream": stream,
#     877                 "stream_options": stream_options,
#     878                 "temperature": temperature,
#     879                 "tool_choice": tool_choice,
#     880                 "tools": tools,
#     881                 "top_logprobs": top_logprobs,
#     882                 "top_p": top_p,
#     883                 "user": user,
#     884             },
#     885             completion_create_params.CompletionCreateParams,
#     886         ),
#     887         options=make_request_options(
#     888             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     889         ),
#     890         cast_to=ChatCompletion,
#     891         stream=stream or False,
#     892         stream_cls=Stream[ChatCompletionChunk],
#     893     )
#
# File ~\VS Code Projects\Science Research\jh_pfx\jh_venv\Lib\site-packages\openai\_base_client.py:1283, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1269 def post(
#    1270     self,
#    1271     path: str,
#    (...)
#    1278     stream_cls: type[_StreamT] | None = None,
#    1279 ) -> ResponseT | _StreamT:
#    1280     opts = FinalRequestOptions.construct(
#    1281         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1282     )
# -> 1283     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\VS Code Projects\Science Research\jh_pfx\jh_venv\Lib\site-packages\openai\_base_client.py:960, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     957 else:
#     958     retries_taken = 0
# --> 960 return self._request(
#     961     cast_to=cast_to,
#     962     options=options,
#     963     stream=stream,
#     964     stream_cls=stream_cls,
#     965     retries_taken=retries_taken,
#     966 )
#
# File ~\VS Code Projects\Science Research\jh_pfx\jh_venv\Lib\site-packages\openai\_base_client.py:1064, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1061         err.response.read()
#    1063     log.debug("Re-raising status error")
# -> 1064     raise self._make_status_error_from_response(err.response) from None
#    1066 return self._process_response(
#    1067     cast_to=cast_to,
#    1068     options=options,
#    (...)
#    1072     retries_taken=retries_taken,
#    1073 )
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-proj-********************************************************************************************************************************************************7p0A. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}

# %%
"""
# PARALLEL API CALLS
from concurrent.futures import ThreadPoolExecutor, as_completed

# Prepare result collection
results = pd.DataFrame(columns=["finding", "ICD10_code", "PFx", "PFx_ICD10_code"])

# Thread-safe collection for results
from threading import Lock
result_lock = Lock()

def process_row(i, row):
    writer = ConversableAgent(
        name="Writer",
        system_message=writer_prompt.format(Incidental_Finding=row['Incidental_Finding'], Reading_Level=SIXTH_GRADE),
        llm_config=llm_config,
        code_execution_config=False,
        human_input_mode="NEVER",
    )

    doctor = ConversableAgent(
        name="Doctor",
        system_message=doctor_prompt.format(Incidental_Finding=row['Incidental_Finding'], ICD10_code=row["ICD10_code"]),
        llm_config=llm_config,
        code_execution_config=False,
        human_input_mode="NEVER",
    )

    readability_checker = ConversableAgent(
        name="Readability_Checker",
        system_message=readability_checker_prompt.format(reading_level=SIXTH_GRADE),
        llm_config=llm_config,
        code_execution_config=False,
        human_input_mode="NEVER",
    )

    icd10_labeler = ConversableAgent(
        name="ICD10_Labeler",
        system_message=ICD10_LABELER_INSTRUCTION,
        llm_config=llm_config,
        code_execution_config=False,
        human_input_mode="NEVER",
    )

    groupchat = autogen.GroupChat(
        agents=[writer, icd10_labeler, doctor, readability_checker],
        messages=[],
        max_round=20,
        speaker_selection_method=state_transition,
    )

    manager = autogen.GroupChatManager(
        groupchat=groupchat,
        llm_config=llm_config,
    )

    manager.initiate_chat(manager, message="""Please play your specified role in 
        generating a patient friendly explanation of an incidental MRI finding.""")

    chat = extract_json_gpt4o(groupchat)

    with result_lock:
        results.loc[i] = {
            "finding": row['Incidental_Finding'],
            "ICD10_code": row['ICD10_code'],
            "PFx": chat.get("PFx", ""),
            "PFx_ICD10_code": chat.get("PFx_ICD10_code", "")
        }

# Parallel execution
with ThreadPoolExecutor(max_workers=5) as executor:
    futures = [executor.submit(process_row, i, row) for i, row in df_eval.iterrows()]
    for future in as_completed(futures):
        future.result()  # Propagate exceptions if any
"""

# %%
results

# %%
# Create a new list to store the labeled ICD10 responses
labeled_icd10_responses = []

# Iterate over each response in pfx_zeroshot_output_all_df and apply the label_icd10s function
for response in results['PFx']:
    labeled_icd10_responses.append(label_icd10s([{'PFx': response}]))

# %%
labeled_icd10_responses

# %%
# Create lists to store the results
agent_icd10_codes = []
icd10_matches = []
pfx_icd10_matches = []
flesch_scores = []

agent_icd10_codes.extend([ list(x[0].values())[0] if x and isinstance(x, list) and len(x) > 0 else "" for x in labeled_icd10_responses])  

for index, row in results.iterrows():
    agent_icd10_code = agent_icd10_codes[index]
    icd10_match = (row["ICD10_code"] == agent_icd10_code)
    icd10_matches.append(icd10_match)

    # compare 
    pfx_icd10_match = (row["PFx_ICD10_code"] == row["ICD10_code"])
    pfx_icd10_matches.append(pfx_icd10_match)

    # Calculate the Flesch Reading Ease score
    flesch_score = textstat.flesch_reading_ease(row['PFx'])
    flesch_scores.append(flesch_score)

# Add the results to the DataFrame
results['_0_agent_icd10_codes'] = agent_icd10_codes
results['_0_icd10_matches'] = icd10_matches
results['_0_pfx_icd10_matches'] = pfx_icd10_matches
results['_0_flesch'] = flesch_scores

# %%
desired_reading_ease = sixth_grade
# Calculate threshold for penalty
if desired_reading_ease >= 55:
    threshold = 10
else:
    threshold = 20

# Create lists to store the results
accuracy_icd10_matches_list = []
accuracy_pfx_matches_list = []
readability_difference_list = []
overall_score_list = []
log_overall_score_list = []

# Iterate over each row in the DataFrame
for index, row in results.iterrows():
    # Calculate accuracy scores
    accuracy_icd10_matches = row["_0_icd10_matches"]
    accuracy_pfx_matches = row["_0_pfx_icd10_matches"]
    flesch_score = row["_0_flesch"]

    # total number of icd10 matches
    total_icd10_matches = accuracy_icd10_matches + accuracy_pfx_matches

    # Adjust weights for overall score
    # Calculate readability score 
    readability_score = flesch_score
    readability_difference = abs(readability_score - desired_reading_ease)

    # Compute the overall score
    overall_score = total_icd10_matches * 0.8  + 0.2 * (1/(readability_difference + 1))

    # Calculate readability score
    readability_difference_log = desired_reading_ease - flesch_score
    if readability_difference_log <= threshold:  # No penalty if difference is within the threshold
        readability_difference_p = 0
    else:  # Apply penalty only if readability exceeds the threshold
        readability_difference_with_threshold = readability_difference_log - threshold
        readability_difference_p = math.log(1 + readability_difference_with_threshold) / math.log(20)

    log_overall_score = total_icd10_matches * 0.8 + readability_difference_log * 0.2

    # Append results to lists
    accuracy_icd10_matches_list.append(float(accuracy_icd10_matches))
    accuracy_pfx_matches_list.append(float(accuracy_pfx_matches))
    readability_difference_list.append(float(readability_difference))
    overall_score_list.append(float(overall_score))
    log_overall_score_list.append(float(log_overall_score))
    

# Create a DataFrame with the results
grades_data = {
    "accuracy_agent_icd10": accuracy_icd10_matches_list,
    "accuracy_pfx_icd10": accuracy_pfx_matches_list,
    "readability_difference": readability_difference_list,
    "overall_score": overall_score_list,
    "log_overall_score": log_overall_score_list,
}
grades = pd.DataFrame(grades_data)
results = pd.concat([results, grades], axis=1)

# %%
grades

# %%
results

# %%
results.to_csv('autogen_4omini_test_30_50_part.csv', index = False)
