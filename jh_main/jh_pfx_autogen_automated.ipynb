# %%
# import necessary libraries 
import pandas as pd
import os
import textstat
from openai import OpenAI
import json
import re
import requests
from dotenv import load_dotenv
import math
import unicodedata

# %%
from autogen import LLMConfig
from autogen import ConversableAgent, LLMConfig
from autogen.agentchat import initiate_group_chat
from autogen.agentchat.group.patterns import RoundRobinPattern
from autogen.agentchat.group import OnCondition, StringLLMCondition
from autogen.agentchat.group import AgentTarget
from autogen.agentchat.group import TerminateTarget

# %%
from pydantic import BaseModel, Field
from typing import Optional
from typing import Annotated

# %%
os.environ['OPENAI_API_KEY'] = ""

# %%
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')
CLIENT = OpenAI(api_key = OPENAI_API_KEY)
OPENAI_MODEL = "gpt-4o"

# %%
llm_config = LLMConfig(
    api_type="openai",
    model="gpt-4o",
    api_key=OPENAI_API_KEY,
)

# %%
# import prompts
from jh_pfx_prompts import example, icd10_example, single_fewshot_icd10_labeling_prompt, writer_prompt,doctor_prompt, readability_checker_prompt, ICD10_LABELER_INSTRUCTION

# %%
#reading levels
PROFESSIONAL = "Professional"
COLLEGE_GRADUATE = "College Graduate"
COLLEGE = "College"
TENTH_TO_TWELTH_GRADE = "10th to 12th grade"
EIGTH_TO_NINTH_GRADE = "8th to 9th grade"
SEVENTH_GRADE = "7th grade"
SIXTH_GRADE = "6th grade"
FIFTH_GRADE = "5th grade"
N_A = "N/A"

# %%
# reading ease variables
fifth_grade = 95
sixth_grade = 85
seventh_grade = 75
eigth_and_ninth_grade = 65
tenth_to_twelfth_grade = 55
college = 40
college_graduate = 20
professional = 5

# %%
def adjust_difference(diff, threshold):
    """Adjust the readability difference based on the threshold."""
    if diff > threshold:
        return diff - threshold
    return 0

# %%
def extract_json_gpt4o(chat_result, verbose=False):
    messages = getattr(chat_result, "chat_history", None) or getattr(chat_result, "messages", [])

    for msg in reversed(messages):
        name = msg.get("name", "").lower()
        if name != "icd10_labeler":
            continue

        content = msg.get("content", "").strip()
        content = unicodedata.normalize("NFKC", content)

        if verbose:
            print(f"[DEBUG] Raw content from {name}:\n{content}")

        content = re.sub(r"```(?:json)?", "", content).strip("` \n")

        try:
            return json.loads(content)
        except json.JSONDecodeError:
            pass

        # fallback with simpler, safe regex
        json_candidates = re.findall(r"\{.*?\}", content, re.DOTALL)
        for candidate in json_candidates:
            try:
                return json.loads(candidate)
            except json.JSONDecodeError:
                continue

        if verbose:
            print(f"[WARN] No valid JSON in {name}'s message.")
        return None

    print("[WARN] No message from 'icd10_labeler' found.")
    return None

# %%
def extract_json_icd10(groupchat):
    """
    Extracts the first valid JSON object from the 'content' of messages,
    handling GPT-4o's potential formatting quirks.
    """
    for msg in reversed(groupchat.messages):
        content = msg.get("content", "").strip()

        # Normalize encoding
        content = unicodedata.normalize("NFKC", content)

        # Remove markdown blocks if they exist
        content = re.sub(r"```json|```", "", content).strip()

        # Try direct JSON parsing first
        try:
            return json.loads(content)
        except json.JSONDecodeError:
            pass  # Continue if direct parsing fails

        # Extract JSON from mixed text
        json_match = re.search(r"\{.*?\}", content, re.DOTALL)
        if json_match:
            try:
                return json.loads(json_match.group(0))
            except json.JSONDecodeError:
                pass  # Continue if regex extraction fails

    return None

# %%
def label_icd10s(pfx_outputs_json):
    pfx_icd10_fewshot_examples = ""
    for i, row in df_fewshot.iterrows():
        pfx_icd10_fewshot_examples += icd10_example.format(**row)

    pfx_icd10_codes = []
    for pfx_output in pfx_outputs_json:
        try:
            prompt = single_fewshot_icd10_labeling_prompt.format(
                examples=pfx_icd10_fewshot_examples,
                PFx=pfx_output['PFx']
            )
        except Exception as e:
            print("ERROR: %s" % pfx_output)
            return

        response = CLIENT.chat.completions.create(
            model=OPENAI_MODEL,
            temperature=0.0,
            messages=[
                {"role": "system", "content": "You are an ICD10 medical coder for incidental findings."},
                {"role": "user", "content": prompt}
            ],
            stream=False,
        )
        
        # Create a simple wrapper object with a 'messages' attribute as a list of dictionaries.
        wrapper = type("Wrapper", (), {})()
        # Convert the ChatCompletionMessage to a dictionary.
        wrapper.messages = [{
            "role": response.choices[0].message.role,
            "content": response.choices[0].message.content
        }]
        
        pfx_icd10_codes.append(wrapper)
        
    return list(map(extract_json_icd10, pfx_icd10_codes))

# %%
df_eval = pd.read_csv('pfx_incidental_findings.csv', skiprows = range(1, 271), nrows = 14)

# %%
df_eval
# Out:
#    Body Part            Organ                     Incidental_Finding  \
# 0       Head          Pharynx                   Pharyngeal Wall Mass
# 1       Head        Pituitary                 Pituitary Microadenoma
# 2       Head  Salivary Glands                           Parotid Cyst
# 3       Head  Salivary Glands                           Sialadenitis
# 4       Head  Salivary Glands                   Salivary Gland Stone
# 5       Head  Salivary Glands                    Pleomorphic Adenoma
# 6       Head            Scalp                         Scalp Hematoma
# 7       Head          Sinuses          Mucosal Thickening in Sinuses
# 8       Head          Sinuses                            Sinus Polyp
# 9       Head          Sinuses  Mucosal Thickening in Maxillary Sinus
# 10      Head          Sinuses           Frontal Sinus Retention Cyst
# 11      Head          Sinuses                      Ethmoid Sinusitis
# 12      Head          Sinuses             Maxillary Sinus Hypoplasia
# 13      Head            Skull                         Skull Fracture
#
#    ICD10_code                        ICD-10 Code Description
# 0       R22.1        Localized swelling, mass and lump, neck
# 1       D35.2             Benign neoplasm of pituitary gland
# 2       K11.6                     Mucocele of salivary gland
# 3      K11.20                     Sialoadenitis, unspecified
# 4       K11.5                                 Sialolithiasis
# 5       D11.0               Benign neoplasm of parotid gland
# 6    S00.03XA          Contusion of scalp, initial encounter
# 7       J32.9                 Chronic sinusitis, unspecified
# 8       J33.8                          Other polyp of sinus
# 9       J32.0                    Chronic maxillary sinusitis
# 10      J34.1      Cyst and mucocele of nose and nasal sinus
# 11      J32.2                    Chronic ethmoidal sinusitis
# 12      Q30.8         Other congenital malformations of nose
# 13   S02.0XXA  Fracture of vault of skull, initial encounter

# %%
df_fewshot = pd.read_csv('pfx_fewshot_examples_college.csv')

# %%
def calculate_fres(
    pfx_text: Annotated[str, "A patient-friendly explanation string."]
) -> dict:
    """Calculate the Flesch Reading Ease Score and estimated reading level for a given explanation."""
    
    def count_syllables(word):
        word = word.lower()
        word = re.sub(r'[^a-z]', '', word)
        if not word:
            return 0
        syllables = re.findall(r'[aeiouy]+', word)
        if word.endswith("e") and not word.endswith("le"):
            syllables = syllables[:-1]
        return max(1, len(syllables))

    sentences = re.split(r'[.!?]', pfx_text)
    sentences = [s.strip() for s in sentences if s.strip()]
    num_sentences = len(sentences)

    words = re.findall(r'\b\w+\b', pfx_text)
    num_words = len(words)
    num_syllables = sum(count_syllables(word) for word in words)

    if num_sentences == 0 or num_words == 0:
        return {"error": "Input must contain at least one sentence and one word."}

    fres = 206.835 - 1.015 * (num_words / num_sentences) - 84.6 * (num_syllables / num_words)

    if fres >= 90:
        grade_level = "5th grade"
    elif fres >= 80:
        grade_level = "6th grade"
    elif fres >= 70:
        grade_level = "7th grade"
    elif fres >= 60:
        grade_level = "8th–9th grade"
    elif fres >= 50:
        grade_level = "10th–12th grade"
    elif fres >= 30:
        grade_level = "College"
    elif fres >= 10:
        grade_level = "College graduate"
    else:
        grade_level = "Professional"

    return {
        "FRES": round(fres, 2),
        "Reading_Level": grade_level
    }

# %%
class WriterOutput(BaseModel):
    finding: str = Field(..., description="Name of incidental finding")
    ICD10_Code: str = Field(..., description="The ICD-10 code for the incidental finding")
    PFx: str = Field(..., description="Patient-friendly explanation of the finding")

class LabelerOutput(BaseModel):
    finding: str = Field(..., description="Name of incidental finding")
    ICD10_Code: str = Field(..., description="The ICD-10 code given by writer")
    PFx: str = Field(..., description="The patient-friendly explanation given by writer")
    PFx_ICD10_Code: str = Field(..., description="The ICD-10 code you determine based off of PFx")

class DoctorReadabilityOutput(BaseModel):
    Verdict: str = Field(..., description="Overall judgment about the explanation, accurate or inaccurate")
    Explanation: Optional[str] = Field(None, description="Why the verdict was given")
    Improvements: Optional[str] = Field(None, description="Suggested changes to improve readability or accuracy")

# %%
llm_config = LLMConfig(
    api_type="openai",
    model="gpt-4o",
    api_key=OPENAI_API_KEY,
)

writer_config=LLMConfig(
    api_type="openai",
    model="gpt-4o",
    api_key=OPENAI_API_KEY,
    response_format=WriterOutput,
)

labeler_config = LLMConfig(
    api_type="openai",
    model="gpt-4o",
    api_key=OPENAI_API_KEY,
    response_format=LabelerOutput,
)

doctor_config = LLMConfig(
    api_type="openai",
    model="gpt-4o",
    api_key=OPENAI_API_KEY,
    response_format=DoctorReadabilityOutput,
)

readability_config=LLMConfig(
    api_type="openai",
    model="gpt-4o",
    api_key=OPENAI_API_KEY,
    response_format=DoctorReadabilityOutput,
    
)

# %%
results = pd.DataFrame(columns=["finding", "ICD10_code", "PFx", "PFx_ICD10_Code"])
for i, row in df_eval.iterrows():
    with llm_config:
        writer = ConversableAgent(
            name = "writer",
            system_message = writer_prompt.format(Incidental_Finding = row['Incidental_Finding'], Reading_Level = SIXTH_GRADE),
            llm_config = writer_config,
        )
    
        icd10_labeler = ConversableAgent(
            name = "icd10_labeler",
            system_message = ICD10_LABELER_INSTRUCTION,
            llm_config = labeler_config,
            code_execution_config=False,
        )
    
        doctor = ConversableAgent( 
            name = "Doctor",
            system_message = doctor_prompt.format(Incidental_Finding = row['Incidental_Finding'], ICD10_code = row["ICD10_code"]),
            llm_config = doctor_config,
            code_execution_config=False,
        )
    
        readability_checker = ConversableAgent(
            name = "Readability_Checker",
            system_message = readability_checker_prompt.format(reading_level = SIXTH_GRADE),
            llm_config = readability_config,
            code_execution_config=False,
            functions=[calculate_fres],
        )
    
        pattern = RoundRobinPattern(
            initial_agent = writer,
            agents = [writer, icd10_labeler, doctor, readability_checker],
        )

        writer.handoffs.set_after_work(AgentTarget(icd10_labeler))
    
        icd10_labeler.handoffs.set_after_work(AgentTarget(doctor))

        doctor.handoffs.add_llm_conditions([
            OnCondition(
                target=AgentTarget(readability_checker),
                condition=StringLLMCondition(prompt="If the response is medically accurate, send the response to the readability_checker."),
            ),
            OnCondition(
                target=AgentTarget(writer),
                condition=StringLLMCondition(prompt="""If the response is medically inaccuare or the original and pfx_icd10_codes are signifigantly different, 
                send the response back to the writer agent with an explanation of why it was sent back and suggestions for improvement in medical accuracy."""),
            ),
        ])

        readability_checker.handoffs.add_llm_conditions([
            OnCondition(
                target=AgentTarget(writer),
                condition=StringLLMCondition("""If the response does not meet the criteria for the desired reading level, send it back to the writer agent
                with an explanation of why it wasn't readable enough and suggestions for improving the readability."""),
            ),
            OnCondition(
              target=TerminateTarget(),
                condition=StringLLMCondition("If the response meets the readability criteria, send it to TerminateTarget."),
            ),
        ])
    

        result, context, last_agent = initiate_group_chat(
            pattern = pattern,
            messages = """Please play your specified role in generating a patient friendly explanation of an inicidental MRI finding.""",
            max_rounds = 20,
        )

        chat = extract_json_gpt4o(result)

        results.loc[i] = {
        "finding": row['Incidental_Finding'],
        "ICD10_code": row['ICD10_code'],
        "PFx": chat.get("PFx", ""),
        "PFx_ICD10_Code": chat.get("PFx_ICD10_Code", "")
        }
# Out:
# _User (to chat_manager):
#
# Please play your specified role in generating a patient friendly explanation of an inicidental MRI finding.
#
# --------------------------------------------------------------------------------
#
# Next speaker: writer
#
#
# >>>>>>>> USING AUTO REPLY...
# writer (to chat_manager):
#
# {"finding":"Pharyngeal Wall Mass","ICD10_Code":"C10.9","PFx":"The doctors found something a little unexpected when they were looking at your test results. They noticed a mass, or a lump, on the wall of your throat. This area is known as the pharyngeal wall, which is just a fancy term for the part of your throat that helps you swallow and speak. \n\nIt’s like if you were exploring a cave, and you found a small bump on the wall that you hadn’t noticed before. It might be nothing, but it’s a good idea to check it out more closely to see what it might be."}
#
# --------------------------------------------------------------------------------
#
# Next speaker: icd10_labeler
#
#
# >>>>>>>> USING AUTO REPLY...
# icd10_labeler (to chat_manager):
#
# {"finding":"Pharyngeal Wall Mass","ICD10_Code":"C10.9","PFx":"The doctors found something a little unexpected when they were looking at your test results. They noticed a mass, or a lump, on the wall of your throat. This area is known as the pharyngeal wall, which is just a fancy term for the part of your throat that helps you swallow and speak. \n\nIt’s like if you were exploring a cave, and you found a small bump on the wall that you hadn’t noticed before. It might be nothing, but it’s a good idea to check it out more closely to see what it might be.","PFx_ICD10_Code":"D49.2"}
#
# --------------------------------------------------------------------------------
#
# Next speaker: Doctor
#
#
# >>>>>>>> USING AUTO REPLY...
# Doctor (to chat_manager):
#
# {"Verdict":"Inaccurate","Explanation":"The ICD-10 code used in the patient friendly explanation (D49.2: Neoplasm of unspecified behavior of respiratory system) does not align with the original finding's ICD-10 code (C10.9: Malignant neoplasm of oropharynx, unspecified). This suggests a potential misunderstanding of the severity and nature of the mass. The PFx describes the mass in a non-specific manner without indicating its potential seriousness, which is implied by the original code indicating a malignant neoplasm.","Improvements":"The explanation should specify the potential seriousness of a mass as suggested by the ICD-10 code C10.9. It should address that this code indicates a possible malignant tumor in the oropharynx region and emphasize the necessity for further examination to understand its nature and appropriate treatment."}
#
# --------------------------------------------------------------------------------
#
# Next speaker: Readability_Checker
#
#
# >>>>>>>> USING AUTO REPLY...
# Readability_Checker (to chat_manager):
#
# ***** Suggested tool call (call_69GMcbRe5ZmQimdmQfsNqFFB): calculate_fres *****
# Arguments:
# {"pfx_text": "The doctors found something a little unexpected when they were looking at your test results. They noticed a mass, or a lump, on the wall of your throat. This area is known as the pharyngeal wall, which is just a fancy term for the part of your throat that helps you swallow and speak. \n\nIt’s like if you were exploring a cave, and you found a small bump on the wall that you hadn’t noticed before. It might be nothing, but it’s a good idea to check it out more closely to see what it might be."}
# *******************************************************************************
# ***** Suggested tool call (call_siX7bIfJeeo1qdFhfDiuMWIR): calculate_fres *****
# Arguments:
# {"pfx_text": "The explanation should specify the potential seriousness of a mass as suggested by the ICD-10 code C10.9. It should address that this code indicates a possible malignant tumor in the oropharynx region and emphasize the necessity for further examination to understand its nature and appropriate treatment."}
# *******************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Group_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION calculate_fres...
# Call ID: call_69GMcbRe5ZmQimdmQfsNqFFB
# Input arguments: {'pfx_text': 'The doctors found something a little unexpected when they were looking at your test results. They noticed a mass, or a lump, on the wall of your throat. This area is known as the pharyngeal wall, which is just a fancy term for the part of your throat that helps you swallow and speak. \n\nIt’s like if you were exploring a cave, and you found a small bump on the wall that you hadn’t noticed before. It might be nothing, but it’s a good idea to check it out more closely to see what it might be.'}
#
# >>>>>>>> EXECUTING FUNCTION calculate_fres...
# Call ID: call_siX7bIfJeeo1qdFhfDiuMWIR
# Input arguments: {'pfx_text': 'The explanation should specify the potential seriousness of a mass as suggested by the ICD-10 code C10.9. It should address that this code indicates a possible malignant tumor in the oropharynx region and emphasize the necessity for further examination to understand its nature and appropriate treatment.'}
# _Group_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_69GMcbRe5ZmQimdmQfsNqFFB) *****
# {'FRES': 80.79, 'Reading_Level': '6th grade'}
# **********************************************************************
#
# --------------------------------------------------------------------------------
# ***** Response from calling tool (call_siX7bIfJeeo1qdFhfDiuMWIR) *****
# {'FRES': 39.02, 'Reading_Level': 'College'}
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: Readability_Checker
#
#
# >>>>>>>> USING AUTO REPLY...
# Readability_Checker (to chat_manager):
#
# {"Verdict":"Accurate","Explanation":"The provided PFx text has a Flesch Reading Ease Score of 80.79, which places it in the 6th grade reading level category. This aligns with the desired readability target for patient-friendly explanations, making it suitable for general patient understanding.","Improvements":"The alternate explanation text provides additional detail on the seriousness of the mass, but it is rated at a college reading level with a FRES of 39.02. To improve the readability of the detailed explanation to 6th grade level, focus on using simpler language, shorter sentences, and more common terms to explain the potential seriousness of the mass and the importance of further examination."}
#
# --------------------------------------------------------------------------------
#
# Next speaker: writer
#
#
# >>>>>>>> USING AUTO REPLY...
# writer (to chat_manager):
#
# {"finding":"Pharyngeal Wall Mass","ICD10_Code":"C10.9","PFx":"The doctors found something unusual in your throat called a 'pharyngeal wall mass.' This means there's a lump in part of your throat that helps with swallowing and talking. Sometimes, lumps can be harmless, like a pebble on a path, but other times, they can be more serious. It’s important to learn more about this lump to see if it needs any treatment. The specific code the doctors used suggests they need to be sure it's not a type of cancer, so they'll look at it more closely to know what's best to do next."}
#
# --------------------------------------------------------------------------------
#
# Next speaker: icd10_labeler
#
#
# >>>>>>>> USING AUTO REPLY...
# icd10_labeler (to chat_manager):
#
# {"finding":"Pharyngeal Wall Mass","ICD10_Code":"C10.9","PFx":"The doctors found something unusual in your throat called a 'pharyngeal wall mass.' This means there's a lump in part of your throat that helps with swallowing and talking. Sometimes, lumps can be harmless, like a pebble on a path, but other times, they can be more serious. It’s important to learn more about this lump to see if it needs any treatment. The specific code the doctors used suggests they need to be sure it's not a type of cancer, so they'll look at it more closely to know what's best to do next.","PFx_ICD10_Code":"C10.9"}
#
# --------------------------------------------------------------------------------
#
# Next speaker: Doctor
#
#
# >>>>>>>> USING AUTO REPLY...
# Doctor (to chat_manager):
#
# ***** Suggested tool call (call_Wek3i9gwS4d1SJTaBA7Qnrcy): transfer_to_Readability_Checker_1 *****
# Arguments:
# {}
# **************************************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Group_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION transfer_to_Readability_Checker_1...
# Call ID: call_Wek3i9gwS4d1SJTaBA7Qnrcy
# Input arguments: {}
# _Group_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_Wek3i9gwS4d1SJTaBA7Qnrcy) *****
# Transfer to Readability_Checker
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: Readability_Checker
#
#
# >>>>>>>> USING AUTO REPLY...
# Readability_Checker (to chat_manager):
#
# ***** Suggested tool call (call_MNWdfNH55BORsyX0PaAAO4uP): calculate_fres *****
# Arguments:
# {"pfx_text":"The doctors found something unusual in your throat called a 'pharyngeal wall mass.' This means there's a lump in part of your throat that helps with swallowing and talking. Sometimes, lumps can be harmless, like a pebble on a path, but other times, they can be more serious. It’s important to learn more about this lump to see if it needs any treatment. The specific code the doctors used suggests they need to be sure it's not a type of cancer, so they'll look at it more closely to know what's best to do next."}
# *******************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Group_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION calculate_fres...
# Call ID: call_MNWdfNH55BORsyX0PaAAO4uP
# Input arguments: {'pfx_text': "The doctors found something unusual in your throat called a 'pharyngeal wall mass.' This means there's a lump in part of your throat that helps with swallowing and talking. Sometimes, lumps can be harmless, like a pebble on a path, but other times, they can be more serious. It’s important to learn more about this lump to see if it needs any treatment. The specific code the doctors used suggests they need to be sure it's not a type of cancer, so they'll look at it more closely to know what's best to do next."}
# _Group_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_MNWdfNH55BORsyX0PaAAO4uP) *****
# {'FRES': 74.86, 'Reading_Level': '7th grade'}
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: Readability_Checker
#
#
# >>>>>>>> USING AUTO REPLY...
# Readability_Checker (to chat_manager):
#
# {"Verdict":"Inaccurate","Explanation":"The revised explanation has a Flesch Reading Ease Score of 74.86, which places it at a 7th grade reading level. This does not meet the desired 6th grade reading level target.","Improvements":"To align the text with a 6th grade reading level, simplify complex ideas further, split long sentences into shorter ones, and use more straightforward vocabulary. Avoid using terms that might require additional explanations or imply complexity, such as 'pharyngeal' and 'specific code,' or provide simpler alternatives or descriptions."}
#
# --------------------------------------------------------------------------------
#
# Next speaker: writer
#
#
# >>>>>>>> USING AUTO REPLY...
# writer (to chat_manager):
#
# {"finding":"Pharyngeal Wall Mass","ICD10_Code":"C10.9","PFx":"The doctors found a lump in your throat, called a 'pharyngeal wall mass.' This is the part of your throat that helps you swallow and talk. Think of it like finding a bump in the road that you didn’t expect. Sometimes, these lumps are not a big deal, but other times, they can be more serious. The doctors want to make sure it’s not dangerous, like cancer. They will check it carefully to figure out what to do next. It's important to know what this lump really means for your health."}
#
# --------------------------------------------------------------------------------
#
# Next speaker: icd10_labeler
#
#
# >>>>>>>> USING AUTO REPLY...
# icd10_labeler (to chat_manager):
#
# {"finding":"Pharyngeal Wall Mass","ICD10_Code":"C10.9","PFx":"The doctors found a lump in your throat, called a 'pharyngeal wall mass.' This is the part of your throat that helps you swallow and talk. Think of it like finding a bump in the road that you didn’t expect. Sometimes, these lumps are not a big deal, but other times, they can be more serious. The doctors want to make sure it’s not dangerous, like cancer. They will check it carefully to figure out what to do next. It's important to know what this lump really means for your health.","PFx_ICD10_Code":"C10.9"}
#
# --------------------------------------------------------------------------------
#
# Next speaker: Doctor
#
#
# >>>>>>>> USING AUTO REPLY...
# Doctor (to chat_manager):
#
# ***** Suggested tool call (call_oTqo3tPbFpU4QL5pW4ZYCIQt): transfer_to_Readability_Checker_1 *****
# Arguments:
# {}
# **************************************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Group_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION transfer_to_Readability_Checker_1...
# Call ID: call_oTqo3tPbFpU4QL5pW4ZYCIQt
# Input arguments: {}
# _Group_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_oTqo3tPbFpU4QL5pW4ZYCIQt) *****
# Transfer to Readability_Checker
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: Readability_Checker
#
#
# >>>>>>>> USING AUTO REPLY...
# Readability_Checker (to chat_manager):
#
# ***** Suggested tool call (call_KTf73xgw3KtBGHTX4CgBNTQo): calculate_fres *****
# Arguments:
# {"pfx_text":"The doctors found a lump in your throat, called a 'pharyngeal wall mass.' This is the part of your throat that helps you swallow and talk. Think of it like finding a bump in the road that you didn’t expect. Sometimes, these lumps are not a big deal, but other times, they can be more serious. The doctors want to make sure it’s not dangerous, like cancer. They will check it carefully to figure out what to do next. It's important to know what this lump really means for your health."}
# *******************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Group_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION calculate_fres...
# Call ID: call_KTf73xgw3KtBGHTX4CgBNTQo
# Input arguments: {'pfx_text': "The doctors found a lump in your throat, called a 'pharyngeal wall mass.' This is the part of your throat that helps you swallow and talk. Think of it like finding a bump in the road that you didn’t expect. Sometimes, these lumps are not a big deal, but other times, they can be more serious. The doctors want to make sure it’s not dangerous, like cancer. They will check it carefully to figure out what to do next. It's important to know what this lump really means for your health."}
# _Group_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_KTf73xgw3KtBGHTX4CgBNTQo) *****
# {'FRES': 87.01, 'Reading_Level': '6th grade'}
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (ce0241b2-bee3-4289-ae51-04626781aeca): Maximum rounds (20) reached
# _User (to chat_manager):
#
# Please play your specified role in generating a patient friendly explanation of an inicidental MRI finding.
#
# --------------------------------------------------------------------------------
#
# Next speaker: writer
#
#
# >>>>>>>> USING AUTO REPLY...
# writer (to chat_manager):
#
# {"finding":"Pituitary Microadenoma","ICD10_Code":"D35.2","PFx":"A pituitary microadenoma is a small growth on your pituitary gland, which is a pea-sized part of the brain that helps control hormones. Hormones are like the body's messengers, telling different parts what to do. This small growth is usually not dangerous and doesn't always cause problems. Think of it like a tiny bump that generally doesn’t change things much. Doctors find these little lumps during checks for something else. Sometimes, people don't even know they have these small growths. It's important to understand these aren't cancer and often don’t require treatment."}
#
# --------------------------------------------------------------------------------
#
# Next speaker: icd10_labeler
#
#
# >>>>>>>> USING AUTO REPLY...
# icd10_labeler (to chat_manager):
#
# {"finding":"Pituitary Microadenoma","ICD10_Code":"D35.2","PFx":"A pituitary microadenoma is a small growth on your pituitary gland, which is a pea-sized part of the brain that helps control hormones. Hormones are like the body's messengers, telling different parts what to do. This small growth is usually not dangerous and doesn't always cause problems. Think of it like a tiny bump that generally doesn’t change things much. Doctors find these little lumps during checks for something else. Sometimes, people don't even know they have these small growths. It's important to understand these aren't cancer and often don’t require treatment.","PFx_ICD10_Code":"D35.2"}
#
# --------------------------------------------------------------------------------
#
# Next speaker: Doctor
#
#
# >>>>>>>> USING AUTO REPLY...
# Doctor (to chat_manager):
#
# {"Verdict":"Accurate","Explanation":"The patient-friendly explanation aligns with the ICD-10 code D35.2, which is for benign neoplasms of the pituitary gland. The explanation correctly describes a pituitary microadenoma as a small, generally non-dangerous growth that is often found incidentally and usually does not require treatment. It also clarifies that it is not cancerous, which is accurate for a benign condition.","Improvements":null}
# ***** Suggested tool call (call_P69ZUC77elBYpB4wVXt0mZfd): transfer_to_Readability_Checker_1 *****
# Arguments:
# {}
# **************************************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Group_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION transfer_to_Readability_Checker_1...
# Call ID: call_P69ZUC77elBYpB4wVXt0mZfd
# Input arguments: {}
# _Group_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_P69ZUC77elBYpB4wVXt0mZfd) *****
# Transfer to Readability_Checker
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: Readability_Checker
#
#
# >>>>>>>> USING AUTO REPLY...
# Readability_Checker (to chat_manager):
#
# ***** Suggested tool call (call_X5WF0TRapzM1pttYcSQNerAg): calculate_fres *****
# Arguments:
# {"pfx_text":"A pituitary microadenoma is a small growth on your pituitary gland, which is a pea-sized part of the brain that helps control hormones. Hormones are like the body's messengers, telling different parts what to do. This small growth is usually not dangerous and doesn't always cause problems. Think of it like a tiny bump that generally doesn’t change things much. Doctors find these little lumps during checks for something else. Sometimes, people don't even know they have these small growths. It's important to understand these aren't cancer and often don’t require treatment."}
# *******************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Group_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION calculate_fres...
# Call ID: call_X5WF0TRapzM1pttYcSQNerAg
# Input arguments: {'pfx_text': "A pituitary microadenoma is a small growth on your pituitary gland, which is a pea-sized part of the brain that helps control hormones. Hormones are like the body's messengers, telling different parts what to do. This small growth is usually not dangerous and doesn't always cause problems. Think of it like a tiny bump that generally doesn’t change things much. Doctors find these little lumps during checks for something else. Sometimes, people don't even know they have these small growths. It's important to understand these aren't cancer and often don’t require treatment."}
# _Group_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_X5WF0TRapzM1pttYcSQNerAg) *****
# {'FRES': 64.59, 'Reading_Level': '8th–9th grade'}
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: Readability_Checker
#
#
# >>>>>>>> USING AUTO REPLY...
# Readability_Checker (to chat_manager):
#
# {"Verdict":"Not readable enough","Explanation":"The explanation is currently at an 8th to 9th-grade reading level with a Flesch Reading Ease Score of 64.59, which is higher than the desired 6th-grade level. This means the explanation may be too complex for 6th-grade students to easily comprehend.","Improvements":"Simplify sentence structure and reduce the use of multisyllabic words. Try to break down complex ideas into shorter sentences and use more common vocabulary that is likely to be understood by a younger audience. Reducing the number of words per sentence and syllables per word can help achieve a lower reading level."}
#
# --------------------------------------------------------------------------------
#
# Next speaker: writer
#
#
# >>>>>>>> USING AUTO REPLY...
# writer (to chat_manager):
#
# {"finding":"Pituitary Microadenoma","ICD10_Code":"D35.2","PFx":"A pituitary microadenoma is a tiny growth on the pituitary gland, which is a small part of the brain that helps control hormones. Hormones help send messages all over your body, like telling it when to grow or how to feel. This little growth is usually harmless and doesn’t cause trouble. Imagine it as a little bump that doesn't do much. Doctors often find it by accident when checking for something else. Many people don’t even know they have it. It's important to remember that it's not cancer and usually doesn’t need any treatment."}
#
# --------------------------------------------------------------------------------
#
# Next speaker: icd10_labeler
#
#
# >>>>>>>> USING AUTO REPLY...
# icd10_labeler (to chat_manager):
#
# {"finding":"Pituitary Microadenoma","ICD10_Code":"D35.2","PFx":"A pituitary microadenoma is a tiny growth on the pituitary gland, which is a small part of the brain that helps control hormones. Hormones help send messages all over your body, like telling it when to grow or how to feel. This little growth is usually harmless and doesn’t cause trouble. Imagine it as a little bump that doesn't do much. Doctors often find it by accident when checking for something else. Many people don’t even know they have it. It's important to remember that it's not cancer and usually doesn’t need any treatment.","PFx_ICD10_Code":"D35.2"}
#
# --------------------------------------------------------------------------------
#
# Next speaker: Doctor
#
#
# >>>>>>>> USING AUTO REPLY...
# Doctor (to chat_manager):
#
# ***** Suggested tool call (call_SoDugKKcEdMEM2llLpqUutdB): transfer_to_Readability_Checker_1 *****
# Arguments:
# {}
# **************************************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Group_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION transfer_to_Readability_Checker_1...
# Call ID: call_SoDugKKcEdMEM2llLpqUutdB
# Input arguments: {}
# _Group_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_SoDugKKcEdMEM2llLpqUutdB) *****
# Transfer to Readability_Checker
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: Readability_Checker
#
#
# >>>>>>>> USING AUTO REPLY...
# Readability_Checker (to chat_manager):
#
# ***** Suggested tool call (call_g6FCm3EQF29SbM1A0qY9NEug): calculate_fres *****
# Arguments:
# {"pfx_text":"A pituitary microadenoma is a tiny growth on the pituitary gland, which is a small part of the brain that helps control hormones. Hormones help send messages all over your body, like telling it when to grow or how to feel. This little growth is usually harmless and doesn’t cause trouble. Imagine it as a little bump that doesn't do much. Doctors often find it by accident when checking for something else. Many people don’t even know they have it. It's important to remember that it's not cancer and usually doesn’t need any treatment."}
# *******************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Group_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION calculate_fres...
# Call ID: call_g6FCm3EQF29SbM1A0qY9NEug
# Input arguments: {'pfx_text': "A pituitary microadenoma is a tiny growth on the pituitary gland, which is a small part of the brain that helps control hormones. Hormones help send messages all over your body, like telling it when to grow or how to feel. This little growth is usually harmless and doesn’t cause trouble. Imagine it as a little bump that doesn't do much. Doctors often find it by accident when checking for something else. Many people don’t even know they have it. It's important to remember that it's not cancer and usually doesn’t need any treatment."}
# _Group_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_g6FCm3EQF29SbM1A0qY9NEug) *****
# {'FRES': 67.13, 'Reading_Level': '8th–9th grade'}
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: Readability_Checker
#
#
# >>>>>>>> USING AUTO REPLY...
# Readability_Checker (to chat_manager):
#
# {"Verdict":"Not readable enough","Explanation":"The revised explanation still scores at an 8th to 9th-grade reading level with a Flesch Reading Ease Score of 67.13, which is higher than the desired 6th-grade level. This indicates that the explanation may still be somewhat complex for sixth-grade reading comprehension.","Improvements":"Further simplify the text by using even more straightforward language and shorter sentences. Consider using simpler words to replace terms like \"harmful,\" \"messages,\" or \"checking\" to bring the reading level closer to the 6th-grade target. Aim to further reduce sentence lengths and retain fewer complex words."}
#
# --------------------------------------------------------------------------------
#
# Next speaker: writer
#
#
# >>>>>>>> USING AUTO REPLY...
# writer (to chat_manager):
#
# {"finding":"Pituitary Microadenoma","ICD10_Code":"D35.2","PFx":"A pituitary microadenoma is a very small lump on the pituitary gland. This gland is a tiny part of your brain that controls important things like growth and feelings. The small lump is usually safe and does not cause problems. Think of it as a tiny bump that doesn't change anything. Doctors often find it by accident when they look for something else. Many people do not even know they have it. Remember, it is not cancer. Most of the time, it does not need any care or treatment."}
#
# --------------------------------------------------------------------------------
#
# Next speaker: icd10_labeler
#
#
# >>>>>>>> USING AUTO REPLY...
# icd10_labeler (to chat_manager):
#
# {"finding":"Pituitary Microadenoma","ICD10_Code":"D35.2","PFx":"A pituitary microadenoma is a very small lump on the pituitary gland. This gland is a tiny part of your brain that controls important things like growth and feelings. The small lump is usually safe and does not cause problems. Think of it as a tiny bump that doesn't change anything. Doctors often find it by accident when they look for something else. Many people do not even know they have it. Remember, it is not cancer. Most of the time, it does not need any care or treatment.","PFx_ICD10_Code":"D35.2"}
#
# --------------------------------------------------------------------------------
#
# Next speaker: Doctor
#
#
# >>>>>>>> USING AUTO REPLY...
# Doctor (to chat_manager):
#
# ***** Suggested tool call (call_GeBBUprcXiVN3lyLCCVSvwTf): transfer_to_Readability_Checker_1 *****
# Arguments:
# {}
# **************************************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Group_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION transfer_to_Readability_Checker_1...
# Call ID: call_GeBBUprcXiVN3lyLCCVSvwTf
# Input arguments: {}
# _Group_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_GeBBUprcXiVN3lyLCCVSvwTf) *****
# Transfer to Readability_Checker
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: Readability_Checker
#
#
# >>>>>>>> USING AUTO REPLY...
# Readability_Checker (to chat_manager):
#
# ***** Suggested tool call (call_s4Gzl1mjoypeeulW2Tu1alUf): calculate_fres *****
# Arguments:
# {"pfx_text":"A pituitary microadenoma is a very small lump on the pituitary gland. This gland is a tiny part of your brain that controls important things like growth and feelings. The small lump is usually safe and does not cause problems. Think of it as a tiny bump that doesn't change anything. Doctors often find it by accident when they look for something else. Many people do not even know they have it. Remember, it is not cancer. Most of the time, it does not need any care or treatment."}
# *******************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (21b44c21-f1eb-4481-98f7-5f4ba86e6a6c): Maximum rounds (20) reached
# _User (to chat_manager):
#
# Please play your specified role in generating a patient friendly explanation of an inicidental MRI finding.
#
# --------------------------------------------------------------------------------
#
# Next speaker: writer
#
#
# >>>>>>>> USING AUTO REPLY...
# writer (to chat_manager):
#
# {"finding":"Parotid Cyst","ICD10_Code":"K11.8","PFx":"A parotid cyst is like a small balloon filled with fluid in one of the salivary glands located near your jaw, called the parotid gland. The parotid gland is one of the glands in your mouth that helps you chew and digest food by producing saliva. Sometimes, for various reasons, a cyst can form in this gland. It usually doesn't cause any pain or problems. However, because it grows in a sensitive area, it may affect certain movements or feel a bit different depending on its size. Doctors often monitor them to ensure they're safe and not causing any issues."}
#
# --------------------------------------------------------------------------------
#
# Next speaker: icd10_labeler
#
#
# >>>>>>>> USING AUTO REPLY...
# icd10_labeler (to chat_manager):
#
# {"finding":"Parotid Cyst","ICD10_Code":"K11.8","PFx":"A parotid cyst is like a small balloon filled with fluid in one of the salivary glands located near your jaw, called the parotid gland. The parotid gland is one of the glands in your mouth that helps you chew and digest food by producing saliva. Sometimes, for various reasons, a cyst can form in this gland. It usually doesn't cause any pain or problems. However, because it grows in a sensitive area, it may affect certain movements or feel a bit different depending on its size. Doctors often monitor them to ensure they're safe and not causing any issues.","PFx_ICD10_Code":"K11.8"}
#
# --------------------------------------------------------------------------------
#
# Next speaker: Doctor
#
#
# >>>>>>>> USING AUTO REPLY...
# Doctor (to chat_manager):
#
# {"Verdict":"Inaccurate","Explanation":"The ICD-10 code provided for the Parotid Cyst in the PFx is K11.8, whereas the correct ICD-10 code for a Parotid Cyst is K11.6. This discrepancy indicates a potential inaccuracy in the coding and classification of the condition. The explanation itself overlooks the correct categorization and specific characteristics of a parotid cyst as defined by K11.6.","Improvements":"Update the ICD-10 code in the explanation from K11.8 to K11.6 to reflect the accurate classification for a Parotid Cyst. Ensure the description aligns correctly with ICD-10 code K11.6, potentially including information about typical causes or management specifically relevant to parotid cysts."}
# ***** Suggested tool call (call_jheKTGpMDw0p4XHvHdJMEAxO): transfer_to_writer_2 *****
# Arguments:
# {}
# *************************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Group_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION transfer_to_writer_2...
# Call ID: call_jheKTGpMDw0p4XHvHdJMEAxO
# Input arguments: {}
# _Group_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_jheKTGpMDw0p4XHvHdJMEAxO) *****
# Transfer to writer
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: writer
#
#
# >>>>>>>> USING AUTO REPLY...
# writer (to chat_manager):
#
# {"finding":"Parotid Cyst","ICD10_Code":"K11.6","PFx":"A parotid cyst is like a little water balloon that forms inside one of your salivary glands, specifically the parotid gland, which is located just in front of your ears. This gland helps make saliva, the wet stuff in your mouth that keeps it moist and helps you eat. Sometimes, a fluid-filled pocket, called a cyst, can appear in this gland. It might feel a bit funny, but most of the time, it doesn’t hurt or cause any major problems. Doctors usually keep an eye on it to ensure it stays harmless and doesn’t start bothering you."}
#
# --------------------------------------------------------------------------------
#
# Next speaker: icd10_labeler
#
#
# >>>>>>>> USING AUTO REPLY...
# icd10_labeler (to chat_manager):
#
# {"finding":"Parotid Cyst","ICD10_Code":"K11.6","PFx":"A parotid cyst is like a little water balloon that forms inside one of your salivary glands, specifically the parotid gland, which is located just in front of your ears. This gland helps make saliva, the wet stuff in your mouth that keeps it moist and helps you eat. Sometimes, a fluid-filled pocket, called a cyst, can appear in this gland. It might feel a bit funny, but most of the time, it doesn’t hurt or cause any major problems. Doctors usually keep an eye on it to ensure it stays harmless and doesn’t start bothering you.","PFx_ICD10_Code":"K11.6"}
#
# --------------------------------------------------------------------------------
#
# Next speaker: Doctor
#
#
# >>>>>>>> USING AUTO REPLY...
# Doctor (to chat_manager):
#
# {"Verdict":"Accurate","Explanation":"The explanation provided accurately describes a parotid cyst, which aligns with the ICD-10 code K11.6. It explains the location and function of the parotid gland and describes the cyst formation in a patient-friendly manner. The description is simple and addresses potential impacts and the usual benign nature of the condition, which matches the typical clinical understanding of a parotid cyst.","Improvements":null}
# ***** Suggested tool call (call_DXq0qzBv3uKpi3fRaAYXqnkP): transfer_to_Readability_Checker_1 *****
# Arguments:
# {}
# **************************************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Group_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION transfer_to_Readability_Checker_1...
# Call ID: call_DXq0qzBv3uKpi3fRaAYXqnkP
# Input arguments: {}
# _Group_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_DXq0qzBv3uKpi3fRaAYXqnkP) *****
# Transfer to Readability_Checker
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: Readability_Checker
#
#
# >>>>>>>> USING AUTO REPLY...
# Readability_Checker (to chat_manager):
#
# ***** Suggested tool call (call_FkNCqN1gs5Hw3k26fgcSvF8F): calculate_fres *****
# Arguments:
# {"pfx_text": "A parotid cyst is like a little water balloon that forms inside one of your salivary glands, specifically the parotid gland, which is located just in front of your ears. This gland helps make saliva, the wet stuff in your mouth that keeps it moist and helps you eat. Sometimes, a fluid-filled pocket, called a cyst, can appear in this gland. It might feel a bit funny, but most of the time, it doesn’t hurt or cause any major problems. Doctors usually keep an eye on it to ensure it stays harmless and doesn’t start bothering you."}
# *******************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Group_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION calculate_fres...
# Call ID: call_FkNCqN1gs5Hw3k26fgcSvF8F
# Input arguments: {'pfx_text': 'A parotid cyst is like a little water balloon that forms inside one of your salivary glands, specifically the parotid gland, which is located just in front of your ears. This gland helps make saliva, the wet stuff in your mouth that keeps it moist and helps you eat. Sometimes, a fluid-filled pocket, called a cyst, can appear in this gland. It might feel a bit funny, but most of the time, it doesn’t hurt or cause any major problems. Doctors usually keep an eye on it to ensure it stays harmless and doesn’t start bothering you.'}
# _Group_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_FkNCqN1gs5Hw3k26fgcSvF8F) *****
# {'FRES': 70.63, 'Reading_Level': '7th grade'}
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: Readability_Checker
#
#
# >>>>>>>> USING AUTO REPLY...
# Readability_Checker (to chat_manager):
#
# ***** Suggested tool call (call_8K2VwnrnhlM7v5IBER2pkByg): transfer_to_writer_1 *****
# Arguments:
# {}
# *************************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Group_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION transfer_to_writer_1...
# Call ID: call_8K2VwnrnhlM7v5IBER2pkByg
# Input arguments: {}
# _Group_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_8K2VwnrnhlM7v5IBER2pkByg) *****
# Transfer to writer
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: writer
#
#
# >>>>>>>> USING AUTO REPLY...
# writer (to chat_manager):
#
# {"finding":"Parotid Cyst","ICD10_Code":"K11.6","PFx":"A parotid cyst is like a little water balloon that forms inside one of your salivary glands, specifically the parotid gland, which is located just in front of your ears. This gland helps make saliva, the wet stuff in your mouth that keeps it moist and helps you eat. Sometimes, a fluid-filled pocket, called a cyst, can appear in this gland. It might feel a bit funny, but most of the time, it doesn’t hurt or cause any major problems. Doctors usually keep an eye on it to ensure it stays harmless and doesn’t start bothering you."}
#
# --------------------------------------------------------------------------------
#
# Next speaker: icd10_labeler
#
#
# >>>>>>>> USING AUTO REPLY...
# icd10_labeler (to chat_manager):
#
# {"finding":"Parotid Cyst","ICD10_Code":"K11.6","PFx":"A parotid cyst is like a little water balloon that forms inside one of your salivary glands, specifically the parotid gland, which is located just in front of your ears. This gland helps make saliva, the wet stuff in your mouth that keeps it moist and helps you eat. Sometimes, a fluid-filled pocket, called a cyst, can appear in this gland. It might feel a bit funny, but most of the time, it doesn’t hurt or cause any major problems. Doctors usually keep an eye on it to ensure it stays harmless and doesn’t start bothering you.","PFx_ICD10_Code":"K11.6"}
#
# --------------------------------------------------------------------------------
#
# Next speaker: Doctor
#
#
# >>>>>>>> USING AUTO REPLY...
# Doctor (to chat_manager):
#
# {"Verdict":"Accurate","Explanation":"The explanation provided accurately describes a parotid cyst, which aligns with the ICD-10 code K11.6. It explains the location and function of the parotid gland and describes the cyst formation in a patient-friendly manner. The description is simple and addresses potential impacts and the usual benign nature of the condition, which matches the typical clinical understanding of a parotid cyst.","Improvements":null}
# ***** Suggested tool call (call_2TdHB8o0Zl0fjDuPE5eKSeud): transfer_to_Readability_Checker_1 *****
# Arguments:
# {}
# **************************************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Group_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION transfer_to_Readability_Checker_1...
# Call ID: call_2TdHB8o0Zl0fjDuPE5eKSeud
# Input arguments: {}
# _Group_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_2TdHB8o0Zl0fjDuPE5eKSeud) *****
# Transfer to Readability_Checker
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: Readability_Checker
#
#
# >>>>>>>> USING AUTO REPLY...
# Readability_Checker (to chat_manager):
#
# ***** Suggested tool call (call_jB8k3sTKKp9cJ85tqzHAOpIn): transfer_to_writer_1 *****
# Arguments:
# {}
# *************************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Group_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION transfer_to_writer_1...
# Call ID: call_jB8k3sTKKp9cJ85tqzHAOpIn
# Input arguments: {}
# _Group_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_jB8k3sTKKp9cJ85tqzHAOpIn) *****
# Transfer to writer
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: writer
#
#
# >>>>>>>> USING AUTO REPLY...
# writer (to chat_manager):
#
# {"finding":"Parotid Cyst","ICD10_Code":"K11.6","PFx":"A parotid cyst is like a little water balloon that forms inside one of your salivary glands, specifically the parotid gland, which is located just in front of your ears. This gland helps make saliva, the wet stuff in your mouth that keeps it moist and helps you eat. Sometimes, a fluid-filled pocket, called a cyst, can appear in this gland. It might feel a bit funny, but most of the time, it doesn’t hurt or cause any major problems. Doctors usually keep an eye on it to ensure it stays harmless and doesn’t start bothering you."}
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (43a01cd9-fd8d-4c81-a806-d9e91a3825c4): Maximum rounds (20) reached
# _User (to chat_manager):
#
# Please play your specified role in generating a patient friendly explanation of an inicidental MRI finding.
#
# --------------------------------------------------------------------------------
#
# Next speaker: writer
#
#
# >>>>>>>> USING AUTO REPLY...
# writer (to chat_manager):
#
# {"finding":"Sialadenitis","ICD10_Code":"K11.2","PFx":"Sialadenitis is a condition that affects the salivary glands in your mouth. These glands make saliva, which helps you chew, taste, and swallow food. Sometimes, an infection or a small stone can block these glands, making them swell and become painful. Think of it like a traffic jam in a city road where cars can't move smoothly, causing a backup. That’s what happens when the saliva can’t flow easily. You might notice some pain or swelling in your mouth or on your face, especially when you eat. It's important to pay attention to these symptoms."}
#
# --------------------------------------------------------------------------------
#
# Next speaker: icd10_labeler
#
#
# >>>>>>>> USING AUTO REPLY...
# icd10_labeler (to chat_manager):
#
# {"finding":"Sialadenitis","ICD10_Code":"K11.2","PFx":"Sialadenitis is a condition that affects the salivary glands in your mouth. These glands make saliva, which helps you chew, taste, and swallow food. Sometimes, an infection or a small stone can block these glands, making them swell and become painful. Think of it like a traffic jam in a city road where cars can't move smoothly, causing a backup. That’s what happens when the saliva can’t flow easily. You might notice some pain or swelling in your mouth or on your face, especially when you eat. It's important to pay attention to these symptoms.","PFx_ICD10_Code":"K11.2"}
#
# --------------------------------------------------------------------------------
#
# Next speaker: Doctor
#
#
# >>>>>>>> USING AUTO REPLY...
# Doctor (to chat_manager):
#
# {"Verdict":"Inaccurate","Explanation":"The ICD-10 code provided for the finding is K11.20, yet the PFx lists K11.2. While K11.2 is a non-specific code that includes various forms of sialadenitis, K11.20 specifically refers to sialadenitis itself without additional specifications. The contextual explanation should align with K11.20 for precision and accuracy in medical communication. Additionally, the explanation omits potential causes like autoimmune disorders which can also lead to sialadenitis.","Improvements":"Ensure consistency between the ICD-10 code given and the explanation provided. Include causes of sialadenitis such as infections, stones, and autoimmune conditions. Clarify that K11.20 specifies sialadenitis, while K11.2 is a broader category, and adjust the explanation to fit the specific code of K11.20."}
#
# --------------------------------------------------------------------------------
#
# Next speaker: Readability_Checker
#
#
# >>>>>>>> USING AUTO REPLY...
# Readability_Checker (to chat_manager):
#
# ***** Suggested tool call (call_YlmbCliTLa4yS0uCUfpPO436): calculate_fres *****
# Arguments:
# {"pfx_text":"Sialadenitis is a condition that affects the salivary glands in your mouth. These glands make saliva, which helps you chew, taste, and swallow food. Sometimes, an infection or a small stone can block these glands, making them swell and become painful. Think of it like a traffic jam in a city road where cars can't move smoothly, causing a backup. That’s what happens when the saliva can’t flow easily. You might notice some pain or swelling in your mouth or on your face, especially when you eat. It's important to pay attention to these symptoms."}
# *******************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Group_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION calculate_fres...
# Call ID: call_YlmbCliTLa4yS0uCUfpPO436
# Input arguments: {'pfx_text': "Sialadenitis is a condition that affects the salivary glands in your mouth. These glands make saliva, which helps you chew, taste, and swallow food. Sometimes, an infection or a small stone can block these glands, making them swell and become painful. Think of it like a traffic jam in a city road where cars can't move smoothly, causing a backup. That’s what happens when the saliva can’t flow easily. You might notice some pain or swelling in your mouth or on your face, especially when you eat. It's important to pay attention to these symptoms."}
# _Group_Tool_Executor (to chat_manager):
#
# ...
# *******************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Group_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION calculate_fres...
# Call ID: call_E6RZfMrYFb3aXONxMc7yeWEU
# Input arguments: {'pfx_text': "A pleomorphic adenoma is a type of small, usually non-cancerous lump that can form in one of your salivary glands. Salivary glands are the parts in your mouth that make saliva, which is the liquid that helps digest food and keeps your mouth moist. Think of it like a tiny, strange-shaped balloon that puffs up in the wrong place. It's called 'pleomorphic' because it can look different in different people. Most of the time, these lumps don't cause problems, but doctors will want to keep an eye on them to make sure they stay harmless."}
# _Group_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_E6RZfMrYFb3aXONxMc7yeWEU) *****
# {'FRES': 73.08, 'Reading_Level': '7th grade'}
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: Readability_Checker
#
#
# >>>>>>>> USING AUTO REPLY...
# Readability_Checker (to chat_manager):
#
# {"Verdict":"Inaccurate","Explanation":"The explanation provided has a Flesch Reading Ease Score of 73.08, which corresponds to a 7th-grade reading level. This score indicates that the explanation is slightly more complex than the desired 6th-grade level.","Improvements":"To improve the readability, consider simplifying some of the language, breaking down longer sentences into shorter ones, and removing less commonly understood terms or phrases. This will help lower the reading level to match a 6th-grade comprehension."}
#
# --------------------------------------------------------------------------------
#
# Next speaker: writer
#
#
# >>>>>>>> USING AUTO REPLY...
# writer (to chat_manager):
#
# {"finding":"Pleomorphic Adenoma","ICD10_Code":"D11.0","PFx":"A pleomorphic adenoma is a type of small bump that can grow in one of your salivary glands. Salivary glands are in your mouth and make spit, which helps you chew and swallow. Think of it like a tiny, funny-shaped balloon that shows up where it shouldn't be. These lumps are usually not dangerous and don't turn into cancer. Doctors watch them to make sure they stay safe. Most of the time, they don't cause any trouble. It's called 'pleomorphic' because it can look different from person to person."}
#
# --------------------------------------------------------------------------------
#
# Next speaker: icd10_labeler
#
#
# >>>>>>>> USING AUTO REPLY...
# icd10_labeler (to chat_manager):
#
# {"finding":"Pleomorphic Adenoma","ICD10_Code":"D11.0","PFx":"A pleomorphic adenoma is a type of small bump that can grow in one of your salivary glands. Salivary glands are in your mouth and make spit, which helps you chew and swallow. Think of it like a tiny, funny-shaped balloon that shows up where it shouldn't be. These lumps are usually not dangerous and don't turn into cancer. Doctors watch them to make sure they stay safe. Most of the time, they don't cause any trouble. It's called 'pleomorphic' because it can look different from person to person.","PFx_ICD10_Code":"D11.0"}
#
# --------------------------------------------------------------------------------
#
# Next speaker: Doctor
#
#
# >>>>>>>> USING AUTO REPLY...
# Doctor (to chat_manager):
#
# ***** Suggested tool call (call_Wbq4Zfycb8rN2Gp5BgUNmcCD): transfer_to_Readability_Checker_1 *****
# Arguments:
# {}
# **************************************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Group_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION transfer_to_Readability_Checker_1...
# Call ID: call_Wbq4Zfycb8rN2Gp5BgUNmcCD
# Input arguments: {}
# _Group_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_Wbq4Zfycb8rN2Gp5BgUNmcCD) *****
# Transfer to Readability_Checker
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: Readability_Checker
#
#
# >>>>>>>> USING AUTO REPLY...
# Readability_Checker (to chat_manager):
#
# ***** Suggested tool call (call_vByI76hHvIbFY7O1u9cjxNTC): calculate_fres *****
# Arguments:
# {"pfx_text":"A pleomorphic adenoma is a type of small bump that can grow in one of your salivary glands. Salivary glands are in your mouth and make spit, which helps you chew and swallow. Think of it like a tiny, funny-shaped balloon that shows up where it shouldn't be. These lumps are usually not dangerous and don't turn into cancer. Doctors watch them to make sure they stay safe. Most of the time, they don't cause any trouble. It's called 'pleomorphic' because it can look different from person to person."}
# *******************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Group_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION calculate_fres...
# Call ID: call_vByI76hHvIbFY7O1u9cjxNTC
# Input arguments: {'pfx_text': "A pleomorphic adenoma is a type of small bump that can grow in one of your salivary glands. Salivary glands are in your mouth and make spit, which helps you chew and swallow. Think of it like a tiny, funny-shaped balloon that shows up where it shouldn't be. These lumps are usually not dangerous and don't turn into cancer. Doctors watch them to make sure they stay safe. Most of the time, they don't cause any trouble. It's called 'pleomorphic' because it can look different from person to person."}
# _Group_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_vByI76hHvIbFY7O1u9cjxNTC) *****
# {'FRES': 78.91, 'Reading_Level': '7th grade'}
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: Readability_Checker
#
#
# >>>>>>>> USING AUTO REPLY...
# Readability_Checker (to chat_manager):
#
# {"Verdict":"Inaccurate","Explanation":"The revised explanation has a Flesch Reading Ease Score of 78.91, which is still at a 7th-grade reading level, indicating that it remains slightly more complex than the desired 6th-grade level.","Improvements":"To achieve a 6th-grade reading level, further simplify the language, use shorter sentences, and consider replacing less common words with simpler synonyms or phrases. This should help lower the reading difficulty to the target level."}
#
# --------------------------------------------------------------------------------
#
# Next speaker: writer
#
#
# >>>>>>>> USING AUTO REPLY...
# writer (to chat_manager):
#
# {"finding":"Pleomorphic Adenoma","ICD10_Code":"D11.0","PFx":"A pleomorphic adenoma is a lump that grows in the salivary glands, which are inside your mouth. These glands make saliva, or spit, helping you eat and drink. Imagine it as a small balloon you find in a place it shouldn't be. These lumps are not cancer and usually don't change into something harmful. Doctors keep an eye on them to make sure they're not causing any issues. Most of the time, they aren't a problem. 'Pleomorphic' means it can look a bit different in each person."}
#
# --------------------------------------------------------------------------------
#
# Next speaker: icd10_labeler
#
#
# >>>>>>>> USING AUTO REPLY...
# icd10_labeler (to chat_manager):
#
# {"finding":"Pleomorphic Adenoma","ICD10_Code":"D11.0","PFx":"A pleomorphic adenoma is a lump that grows in the salivary glands, which are inside your mouth. These glands make saliva, or spit, helping you eat and drink. Imagine it as a small balloon you find in a place it shouldn't be. These lumps are not cancer and usually don't change into something harmful. Doctors keep an eye on them to make sure they're not causing any issues. Most of the time, they aren't a problem. 'Pleomorphic' means it can look a bit different in each person.","PFx_ICD10_Code":"D11.0"}
#
# --------------------------------------------------------------------------------
#
# Next speaker: Doctor
#
#
# >>>>>>>> USING AUTO REPLY...
# Doctor (to chat_manager):
#
# ***** Suggested tool call (call_IjQKV2kHS7la5tP1rJtqlXbH): transfer_to_Readability_Checker_1 *****
# Arguments:
# {}
# **************************************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Group_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION transfer_to_Readability_Checker_1...
# Call ID: call_IjQKV2kHS7la5tP1rJtqlXbH
# Input arguments: {}
# _Group_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_IjQKV2kHS7la5tP1rJtqlXbH) *****
# Transfer to Readability_Checker
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: Readability_Checker
#
#
# >>>>>>>> USING AUTO REPLY...
# Readability_Checker (to chat_manager):
#
# ***** Suggested tool call (call_naSqWpWsxQp2b6ZrgsGGbdC4): calculate_fres *****
# Arguments:
# {"pfx_text":"A pleomorphic adenoma is a lump that grows in the salivary glands, which are inside your mouth. These glands make saliva, or spit, helping you eat and drink. Imagine it as a small balloon you find in a place it shouldn't be. These lumps are not cancer and usually don't change into something harmful. Doctors keep an eye on them to make sure they're not causing any issues. Most of the time, they aren't a problem. 'Pleomorphic' means it can look a bit different in each person."}
# *******************************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (33be35dc-dfc0-46b7-9ccb-de773871aa1c): Maximum rounds (20) reached
# _User (to chat_manager):
#
# Please play your specified role in generating a patient friendly explanation of an inicidental MRI finding.
#
# --------------------------------------------------------------------------------
#
# Next speaker: writer
#
#
# >>>>>>>> USING AUTO REPLY...
# writer (to chat_manager):
#
# {"finding":"Scalp Hematoma","ICD10_Code":"S00.03","PFx":"A scalp hematoma is like a bruise on the head. It happens when tiny blood vessels under the skin break and make a small pool of blood. You might notice a bump or swelling on your head where the injury happened. This can happen if you bumped your head or fell. Think of it like spilling a drink on a table, where the drink makes a little puddle. Most of the time, a scalp hematoma is not serious and will go away on its own, like how the puddle will dry. It might hurt for a little while, but eventually, it will get better as your body heals."}
#
# --------------------------------------------------------------------------------
#
# Next speaker: icd10_labeler
#
#
# >>>>>>>> USING AUTO REPLY...
# icd10_labeler (to chat_manager):
#
# {"finding":"Scalp Hematoma","ICD10_Code":"S00.03","PFx":"A scalp hematoma is like a bruise on the head. It happens when tiny blood vessels under the skin break and make a small pool of blood. You might notice a bump or swelling on your head where the injury happened. This can happen if you bumped your head or fell. Think of it like spilling a drink on a table, where the drink makes a little puddle. Most of the time, a scalp hematoma is not serious and will go away on its own, like how the puddle will dry. It might hurt for a little while, but eventually, it will get better as your body heals.","PFx_ICD10_Code":"S00.03"}
#
# --------------------------------------------------------------------------------
#
# Next speaker: Doctor
#
#
# >>>>>>>> USING AUTO REPLY...
# Doctor (to chat_manager):
#
# {"Verdict":"Accurate","Explanation":"The patient-friendly explanation of a scalp hematoma aligns well with the ICD-10 code S00.03XA, which is for contusion of the scalp. The explanation describes a scalp hematoma as a \"bruise on the head,\" mentioning the breakage of tiny blood vessels and pooling of blood, which corresponds with a contusion. It also addresses potential causes (bumping the head or falling) and assures that it usually resolves on its own, which is a realistic portrayal of most scalp hematomas.","Improvements":null}
# ***** Suggested tool call (call_btq1phJNRYrrJuHXo0o9kA7V): transfer_to_Readability_Checker_1 *****
# Arguments:
# {}
# **************************************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Group_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION transfer_to_Readability_Checker_1...
# Call ID: call_btq1phJNRYrrJuHXo0o9kA7V
# Input arguments: {}
# _Group_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_btq1phJNRYrrJuHXo0o9kA7V) *****
# Transfer to Readability_Checker
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: Readability_Checker
#
#
# >>>>>>>> USING AUTO REPLY...
# Readability_Checker (to chat_manager):
#
# ***** Suggested tool call (call_6YICTA1QO1G9ehPaKjAWgauX): calculate_fres *****
# Arguments:
# {"pfx_text":"A scalp hematoma is like a bruise on the head. It happens when tiny blood vessels under the skin break and make a small pool of blood. You might notice a bump or swelling on your head where the injury happened. This can happen if you bumped your head or fell. Think of it like spilling a drink on a table, where the drink makes a little puddle. Most of the time, a scalp hematoma is not serious and will go away on its own, like how the puddle will dry. It might hurt for a little while, but eventually, it will get better as your body heals."}
# *******************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Group_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION calculate_fres...
# Call ID: call_6YICTA1QO1G9ehPaKjAWgauX
# Input arguments: {'pfx_text': 'A scalp hematoma is like a bruise on the head. It happens when tiny blood vessels under the skin break and make a small pool of blood. You might notice a bump or swelling on your head where the injury happened. This can happen if you bumped your head or fell. Think of it like spilling a drink on a table, where the drink makes a little puddle. Most of the time, a scalp hematoma is not serious and will go away on its own, like how the puddle will dry. It might hurt for a little while, but eventually, it will get better as your body heals.'}
# _Group_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_6YICTA1QO1G9ehPaKjAWgauX) *****
# {'FRES': 80.73, 'Reading_Level': '6th grade'}
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: Readability_Checker
#
#
# >>>>>>>> USING AUTO REPLY...
# Readability_Checker (to chat_manager):
#
# ***** Suggested tool call (call_qed8HX9px6vuqs09WekMEQyQ): transfer_to_terminate_2 *****
# Arguments:
# {}
# ****************************************************************************************
#
# --------------------------------------------------------------------------------
#
# Next speaker: _Group_Tool_Executor
#
#
# >>>>>>>> EXECUTING FUNCTION transfer_to_terminate_2...
# Call ID: call_qed8HX9px6vuqs09WekMEQyQ
# Input arguments: {}
# _Group_Tool_Executor (to chat_manager):
#
# ***** Response from calling tool (call_qed8HX9px6vuqs09WekMEQyQ) *****
# Terminate
# **********************************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (aad6a30d-5ba6-4dbc-9071-e848a64a5e39): No next speaker selected

# %%
results
# Out:
#                  finding ICD10_code  \
# 0     Orbital Cellulitis     H05.01
# 1       Orbital Fracture     S02.82
# 2    Tonsillar Asymmetry      J35.8
# 3  Tonsillar Hypertrophy      J35.1
#
#                                                  PFx PFx_ICD10_Code
# 0  Orbital cellulitis is when the area around you...         H05.01
# 1  An orbital fracture means that a bone around t...         S02.82
# 2  Tonsillar asymmetry means one of your tonsils ...          J35.8
# 3  Tonsillar hypertrophy means your tonsils are b...          J35.1

# %%
# Create a new list to store the labeled ICD10 responses
labeled_icd10_responses = []

# Iterate over each response in pfx_zeroshot_output_all_df and apply the label_icd10s function
for response in results['PFx']:
    labeled_icd10_responses.append(label_icd10s([{'PFx': response}]))

# %%
labeled_icd10_responses
# Out:
# [[{'ICD10_code': 'H05.01'}],
#  [{'ICD10_code': 'S02.3'}],
#  [{'ICD10_code': 'J35.8'}],
#  [{'ICD10_code': 'J35.1'}]]

# %%
# Create lists to store the results
agent_icd10_codes = []
icd10_matches = []
pfx_icd10_matches = []
flesch_scores = []

agent_icd10_codes.extend([ list(x[0].values())[0] if x and isinstance(x, list) and len(x) > 0 else "" for x in labeled_icd10_responses])  

for index, row in results.iterrows():
    agent_icd10_code = agent_icd10_codes[index]
    icd10_match = (row["ICD10_code"] == agent_icd10_code)
    icd10_matches.append(icd10_match)

    # compare 
    pfx_icd10_match = (row["PFx_ICD10_Code"] == row["ICD10_code"])
    pfx_icd10_matches.append(pfx_icd10_match)

    # Calculate the Flesch Reading Ease score
    flesch_score = textstat.flesch_reading_ease(row['PFx'])
    flesch_scores.append(flesch_score)

# Add the results to the DataFrame
results['_0_agent_icd10_codes'] = agent_icd10_codes
results['_0_icd10_matches'] = icd10_matches
results['_0_pfx_icd10_matches'] = pfx_icd10_matches
results['_0_flesch'] = flesch_scores

# %%
desired_reading_ease = sixth_grade
# Calculate threshold for penalty
if desired_reading_ease >= 55:
    threshold = 10
else:
    threshold = 20

# Create lists to store the results
accuracy_icd10_matches_list = []
accuracy_pfx_matches_list = []
readability_difference_list = []
overall_score_list = []
log_overall_score_list = []

# Iterate over each row in the DataFrame
for index, row in results.iterrows():
    # Calculate accuracy scores
    accuracy_icd10_matches = row["_0_icd10_matches"]
    accuracy_pfx_matches = row["_0_pfx_icd10_matches"]
    flesch_score = row["_0_flesch"]

    # total number of icd10 matches
    total_icd10_matches = accuracy_icd10_matches + accuracy_pfx_matches

    # Adjust weights for overall score
    # Calculate readability score 
    readability_score = flesch_score
    readability_difference = abs(readability_score - desired_reading_ease)

    # Compute the overall score
    overall_score = total_icd10_matches * 0.8  + 0.2 * (1/(readability_difference + 1))

    # Calculate readability score
    readability_difference_log = desired_reading_ease - flesch_score
    if readability_difference_log <= threshold:  # No penalty if difference is within the threshold
        readability_difference_p = 0
    else:  # Apply penalty only if readability exceeds the threshold
        readability_difference_with_threshold = readability_difference_log - threshold
        readability_difference_p = math.log(1 + readability_difference_with_threshold) / math.log(20)

    log_overall_score = total_icd10_matches * 0.8 + readability_difference_log * 0.2

    # Append results to lists
    accuracy_icd10_matches_list.append(float(accuracy_icd10_matches))
    accuracy_pfx_matches_list.append(float(accuracy_pfx_matches))
    readability_difference_list.append(float(readability_difference))
    overall_score_list.append(float(overall_score))
    log_overall_score_list.append(float(log_overall_score))
    

# Create a DataFrame with the results
grades_data = {
    "accuracy_agent_icd10": accuracy_icd10_matches_list,
    "accuracy_pfx_icd10": accuracy_pfx_matches_list,
    "readability_difference": readability_difference_list,
    "overall_score": overall_score_list,
    "log_overall_score": log_overall_score_list,
}
grades = pd.DataFrame(grades_data)
results = pd.concat([results, grades], axis=1)

# %%
grades
# Out:
#    accuracy_agent_icd10  accuracy_pfx_icd10  readability_difference  \
# 0                   1.0                 1.0                    9.76
# 1                   0.0                 1.0                    8.03
# 2                   1.0                 1.0                    0.28
# 3                   1.0                 1.0                    3.37
#
#    overall_score  log_overall_score
# 0       1.618587             -0.352
# 1       0.822148             -0.806
# 2       1.756250              1.544
# 3       1.645767              2.274

# %%
results
# Out:
#                  finding ICD10_code  \
# 0     Orbital Cellulitis     H05.01
# 1       Orbital Fracture     S02.82
# 2    Tonsillar Asymmetry      J35.8
# 3  Tonsillar Hypertrophy      J35.1
#
#                                                  PFx PFx_ICD10_Code  \
# 0  Orbital cellulitis is when the area around you...         H05.01
# 1  An orbital fracture means that a bone around t...         S02.82
# 2  Tonsillar asymmetry means one of your tonsils ...          J35.8
# 3  Tonsillar hypertrophy means your tonsils are b...          J35.1
#
#   _0_agent_icd10_codes  _0_icd10_matches  _0_pfx_icd10_matches  _0_flesch  \
# 0               H05.01              True                  True      94.76
# 1                S02.3             False                  True      93.03
# 2                J35.8              True                  True      85.28
# 3                J35.1              True                  True      81.63
#
#    accuracy_agent_icd10  accuracy_pfx_icd10  readability_difference  \
# 0                   1.0                 1.0                    9.76
# 1                   0.0                 1.0                    8.03
# 2                   1.0                 1.0                    0.28
# 3                   1.0                 1.0                    3.37
#
#    overall_score  log_overall_score
# 0       1.618587             -0.352
# 1       0.822148             -0.806
# 2       1.756250              1.544
# 3       1.645767              2.274

# %%
results.to_csv('autogen_missing_2.csv', index = False)
